# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# ## Project Description

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
#
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# ### Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
#
# • Country code
#
# • Country name

# %% [markdown]
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people

# %% [markdown]
# ### Problem statement : In this dataset predict 2 things :
#
# 1) Average Cost for two
#
# 2) Price range

# %% [markdown]
# Hint :  Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets

# %% [markdown]
# ## Dataset Link-
#
# •	https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
#
# •	https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
# Loading xlx file of country code
df1 = pd.read_excel("D:\Data Science - DataTrained\Internship Projects\Projects Evaluation Phase 3\Country-Code.xlsx")

# %%
# #Loading csv file of Zomato

df2=pd.read_csv('zomato.csv', encoding='latin1')

# %%
# Merging both datasets

df = pd.merge(df1, df2,how='left',on='Country Code')
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %% [markdown]
# # Exploratory Data Analysis EDA

# %%
df.head()
# Out:
#    Country Code Country  Restaurant ID                        Restaurant Name  \
# 0             1   India        3400025                             Jahanpanah
# 1             1   India        3400341                    Rangrezz Restaurant
# 2             1   India        3400005                Time2Eat - Mama Chicken
# 3             1   India        3400021  Chokho Jeeman Marwari Jain Bhojanalya
# 4             1   India        3400017                         Pinch Of Spice
#
#    City                                            Address     Locality  \
# 0  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
# ...

# %%
df.tail()
# Out:
#       Country Code        Country  Restaurant ID  \
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 9546                       The Screaming Eagle        Waterloo
# 9547                             The Thai Bowl        Waterloo
# 9548                Tokyo Japanese Steak House        Waterloo
# 9549  Theo Yianni's Authentic Greek Restaurant         Weirton
# 9550                 Fishpatrick's Crabby Cafe  Winchester Bay
#
#                                           Address        Locality  \
# 9546            228 E 4th St., Waterloo, IA 50703        Waterloo
# 9547      624 Sycamore Street, Waterloo, IA 50703        Waterloo
# 9548        1931 Sears Street, Waterloo, IA 50702        Waterloo
# ...

# %%
#Checking the dimentions of the dataset

df.shape
# Out:
# (9551, 22)

# %% [markdown]
# The dataset has 9551 rows and 22 columns.

# %%
#Checking the columns of the dataset

df.columns.to_list()
# Out:
# ['Country Code',
#  'Country',
#  'Restaurant ID',
#  'Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
# Checking the types of columns

df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# The dataset has three different types of data - object (Categorical data), float64 and int64 (Numerical data).

# %%
# Checking the null values

df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# There are missing values presented in 'Cuisines' column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
# Using heatmap to visualize the null values.

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Checking for dublicate values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The dataframe does not contain any duplicate values.

# %%
#Checking for unique values of each column.

for i in df.columns:
    print(df[i].unique())
    print("\n")
# Out:
# [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
#
#
# ['India' 'Australia' 'Brazil' 'Canada' 'Indonesia' 'New Zealand'
#  'Phillipines' 'Qatar' 'Singapore' 'South Africa' 'Sri Lanka' 'Turkey'
#  'UAE' 'United Kingdom' 'United States']
#
#
# [ 3400025  3400341  3400005 ... 17697332 17694056 17559793]
#
#
# ['Jahanpanah' 'Rangrezz Restaurant' 'Time2Eat - Mama Chicken' ...
#  'Tokyo Japanese Steak House' "Theo Yianni's Authentic Greek Restaurant"
#  "Fishpatrick's Crabby Cafe"]
#
#
# ['Agra' 'Ahmedabad' 'Allahabad' 'Amritsar' 'Aurangabad' 'Bangalore'
#  'Bhopal' 'Bhubaneshwar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Dehradun'
#  'Faridabad' 'Ghaziabad' 'Goa' 'Gurgaon' 'Guwahati' 'Hyderabad' 'Indore'
#  'Jaipur' 'Kanpur' 'Kochi' 'Kolkata' 'Lucknow' 'Ludhiana' 'Mangalore'
#  'Mohali' 'Mumbai' 'Mysore' 'Nagpur' 'Nashik' 'New Delhi' 'Noida'
#  'Panchkula' 'Patna' 'Puducherry' 'Pune' 'Ranchi' 'Secunderabad' 'Surat'
# ...

# %%
#Checking the number of unique values in each column

df.nunique().to_frame("Number of unique values")
# Out:
#                       Number of unique values
# Country Code                               15
# Country                                    15
# Restaurant ID                            9551
# Restaurant Name                          7446
# City                                      141
# Address                                  8918
# Locality                                 1208
# Locality Verbose                         1265
# Longitude                                8120
# Latitude                                 8677
# Cuisines                                 1825
# Average Cost for two                      140
# Currency                                   12
# Has Table booking                           2
# Has Online delivery                         2
# Is delivering now                           2
# Switch to order menu                        1
# Price range                                 4
# Aggregate rating                           33
# ...

# %%
#Checking the value counts of each column.

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
#
#
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# 18398571    1
# 17559793    1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# ...

# %% [markdown]
# ## Separating categorical and numerical columns

# %%
cat_columns = []

for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        cat_columns.append(i)
print('Categorical Columns: ', cat_columns)
print('\n')


num_columns = []

for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num_columns.append(i)
print('Numerical Columns: ', num_columns)
# Out:
# Categorical Columns:  ['Country', 'Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']
#
#
# Numerical Columns:  ['Country Code', 'Restaurant ID', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [markdown]
# We said already that there is 9 missing values in 'Cuisines' column, the column has categorical data so we gonna use Simple Imputer to fill in the misssing values.

# %%
# Using Simle Imputer to fill in the missing data in the categorical columns

from sklearn.impute import SimpleImputer

imp=SimpleImputer(strategy="most_frequent")

df['Cuisines']=imp.fit_transform(df['Cuisines'].values.reshape(-1,1))

# %%
# Checking again for Null values

df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Now we don't have missing values.

# %% [markdown]
# ## Description of the dataset

# %%
# for numerical data

df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# for object data

df.describe(include="object")
# Out:
#        Country  Restaurant Name       City           Address         Locality  \
# count     9551             9551       9551              9551             9551
# unique      15             7446        141              8918             1208
# top      India  Cafe Coffee Day  New Delhi  Sector 41, Noida  Connaught Place
# freq      8652               83       5473                11              122
#
#                   Locality Verbose      Cuisines            Currency  \
# count                         9551          9551                9551
# unique                        1265          1825                  12
# top     Connaught Place, New Delhi  North Indian  Indian Rupees(Rs.)
# freq                           122           945                8652
#
#        Has Table booking Has Online delivery Is delivering now  \
# count               9551                9551              9551
# unique                 2                   2                 2
# ...

# %% [markdown]
# - The mean is slightly bigger than the median in 'Country Code' and 'Restaurant ID' which indicates the data is slightly skewed to the right.
# - The mean is significantly bigger than the median in 'Average Cost for two' and 'Votes' which means most of the data is mainly skewed to the right.
# - The mean is slightly smaller than the median in 'Longitude', 'Latitude' and 'Price range', which means the data is slightly skewed to the left.
# - The mean is significantly bigger than the median in 'Aggregate rating', which means the data is mainly skewed to the left.
# - 'Country' has 15 unique values and the most common one is India
# - 'Restaurant Name' has 7446 unique values and the most common one is Cafe Coffee Day, presented 83 times in the dataset.
# - 'City' has 141 unique values and the most common one is New Delhi, presented 5473 times in the dataset.
# - 'Address' has 8918 unique values and the most common one is Sector 41, Noida, presented 11 times in the dataset.
# - 'Locality' has 1208 unique values and the most common one is Connaught Place, presented 122 times in the dataset.
# - 'Locality Verbose' has 1265 unique values and the most common one is Connaught Place, New Delhi, presented 122 times in the dataset.
# - 'Cuisines' has 1825 unique values and the most common one is North Indian, presented 945 times in the dataset.
# - 'Currency' has 12 unique values and the most common one is Indian Rupees(Rs.), presented 8652 times in the dataset.
# - 'Has Table booking' has 2 unique values and the most common one is No, presented 8393 times in the dataset.
# - 'Has Online delivery' has 2 unique values and the most common one is No, presented 7100 times in the dataset.
# - 'Is delivering now' has 2 unique values and the most common one is No, presented 9517 times in the dataset.
# - 'Switch to order menu' has 1 unique values and the most common one is No, presented 9551 times in the dataset.
# - 'Rating color' has 6 unique values and the most common one is Orange, presented 3737 times in the dataset.
# - 'Rating text' has 6 unique values and the most common one is Average, presented 3737 times in the dataset.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
# Visualizing the Country.

ax=sns.countplot(x='Country', data=df)
plt.xticks(rotation=45, fontsize=6)
print(df['Country'].value_counts())
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# The majority of the restaurants are located in India.

# %%
# Visualization of the 'Restaurant Name

print(df['Restaurant Name'].value_counts())
# Out:
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %% [markdown]
# The dataset includes a wide variety of restaurant names, with 7446 unique names. Most common one is Cafe Coffee Day.

# %%
# Visualization of the 'City'

print(df['City'].value_counts())
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Vineland Station       1
# Yorkton                1
# Bandung                1
# Quezon City            1
# Winchester Bay         1
# Name: City, Length: 141, dtype: int64

# %% [markdown]
# The dataset includes a wide variety of cities, with 141 unique names. Most common one is New Delhi.

# %%
# Visualization of the Address

print(df['Address'].value_counts())
# Out:
# Sector 41, Noida                                                                      11
# Dilli Haat, INA, New Delhi                                                            11
# Greater Kailash (GK) 1, New Delhi                                                     10
# The Imperial, Janpath, New Delhi                                                       9
# The Lalit, Barakhamba Avenue, Barakhamba Road, New Delhi                               8
#                                                                                       ..
# G-4, Local Shopping Complex, Gujranwala Town, New Delhi                                1
# State Bank Colony, Near Nanak Piau Gurudwara, GTK Road, Gujranwala Town, New Delhi     1
# Shop 6 & 7, DDA Market, Near Pentamed Hospital, Gujranwala Town, New Delhi             1
# A-199, Gujranwala Town, New Delhi                                                      1
# ...

# %% [markdown]
# The dataset includes a wide variety of addresses, with 8918 unique names.

# %%
# Visualization of the Locality

print(df['Locality'].value_counts())
# Out:
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
#                   ...
# Waltair Uplands      1
# Armidale             1
# Balingup             1
# Beechworth           1
# Winchester Bay       1
# Name: Locality, Length: 1208, dtype: int64

# %% [markdown]
# The dataset includes a wide variety of locations in the city, with 1208 unique names.

# %%
# Visualization of the 'Locality Verbose'

print(df['Locality Verbose'].value_counts())
# Out:
# Connaught Place, New Delhi             122
# Rajouri Garden, New Delhi               99
# Shahdara, New Delhi                     87
# Defence Colony, New Delhi               86
# Pitampura, New Delhi                    85
#                                       ...
# Hotel Maurya, Lodipur, Patna             1
# Maurya Lok, Fraser Road Area, Patna      1
# Patliputra Colony, Patna                 1
# Heritage Town, Puducherry                1
# Winchester Bay, Winchester Bay           1
# Name: Locality Verbose, Length: 1265, dtype: int64

# %% [markdown]
# The dataset includes a wide variety of locations descriptions, with 1265 unique names.

# %%
# Visualization of the 'Cuisines'

print(df['Cuisines'].value_counts())
# Out:
# North Indian                                 945
# North Indian, Chinese                        511
# Fast Food                                    354
# Chinese                                      354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Mexican, Continental                     1
# North Indian, Continental, Asian, Italian      1
# Continental, Cafe                              1
# North Indian, Biryani, Mughlai                 1
# Burger, Greek, Sandwich                        1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# The dataset includes a wide variety of cuisines, with 1825 unique names. The most common one is North Indian.

# %%
# Visualization of the 'Currency'

sns.countplot(x='Currency',data=df)
plt.xticks(rotation=45, fontsize=6)
print(df['Currency'].value_counts())
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(ï¿½ï¿½)              80
# Brazilian Real(R$)          60
# Rand(R)                     60
# Emirati Diram(AED)          60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %% [markdown]
# The majority of the restaurants using Indian Rupees as curency, second common is US Dollars.

# %%
# Visualization of the 'Has Table booking'

sns.countplot(x='Has Table booking',data=df)
print(df['Has Table booking'].value_counts())
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %% [markdown]
# The majority of the restaurants don`t require table booking.

# %%
# Visualization of the 'Has Online delivery'

sns.countplot(x='Has Online delivery',data=df)
print(df['Has Online delivery'].value_counts())
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %% [markdown]
# The majority of the restaurants don`t have online delivery.

# %%
# Visualization of the 'Is delivering now'

sns.countplot(x='Is delivering now',data=df)
print(df['Is delivering now'].value_counts())
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %% [markdown]
# The majority of the restaurants don`t deliver.

# %%
# Visualization of the 'Switch to order menu'

sns.countplot(x='Switch to order menu',data=df)
print(df['Switch to order menu'].value_counts())
# Out:
# No    9551
# Name: Switch to order menu, dtype: int64

# %% [markdown]
# 'Switch to order menu' has only one unique value.

# %%
# Visualization of the 'Rating color'

sns.countplot(x='Rating color',data=df, color='y')
print(df['Rating color'].value_counts())
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %% [markdown]
# The most common Rating color is Orange, followed by white and yellow.

# %%
# Visualization of the 'Rating text'

sns.countplot(x='Rating text',data=df)
print(df['Rating text'].value_counts())
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %% [markdown]
# The majority of the restaurants have Average rating, followed by Not rated and Good.

# %%
# Value counts for the Numerical columns

for i in num_columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# 18398571    1
# 17559793    1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
#  0.000000      498
#  77.353663      19
#  77.230412      12
#  77.088688      10
#  77.251426       9
#               ...
#  77.303872       1
#  77.307939       1
#  77.299597       1
#  77.299004       1
# -124.175346      1
# Name: Longitude, Length: 8120, dtype: int64
#
#
# 0.000000     498
# 28.574309     16
# 28.551456      9
# 28.574300      9
# 28.597103      8
#             ...
# 28.701519      1
# 28.699157      1
# 28.694336      1
# 28.699116      1
# 43.678998      1
# ...

# %%
#Visiualizing the numerical columns

plt.figure(figsize=(20,30), facecolor='white')
plotnumber=1
for col in num_columns:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber) 
        sns.histplot(x=df[col], data=df)
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - 'Country Code' - most common country code is 1.
# - 'Restaurant ID' - The dataset includes a wide variety of restaurants ids.
# - 'Longitude' - The dataset includes a wide variety of Longitudes. The most common one is 0.000000.
# - 'Latitude' - The dataset includes a wide variety of Latitude. The most common one is 0.000000.
# - 'Average Cost for two' - The average cost for two varies but the most commons are in the range between 650 and 900.
# - 'Price range' - There are four different price ranges, the most common one is 1.
# - 'Aggregate rating' - There are different aggregate ratings, the most common one is 0. The other common ones are in the range of 3-3.8.
# - 'Votes' -  The dataset includes a wide variety of votes. The most common one is 0.

# %% [markdown]
# ## Bivariate Analysis

# %%
# Visualization of Categorical column Vs Average Cost for two

plt.figure(figsize=(20,25))
p=1

for i in cat_columns:
    if p<=20:
        plt.subplot(10,2,p)
        ax= sns.barplot(x=i, y='Average Cost for two',data=df)
        plt.xticks(fontsize=8)
    p+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - The average cost for two vs Country - The average cost for two varies significantly across different countries. India has the highest average cost for two, followed by Indonesia, Sri Lanka, and UAE.
# - Average Cost for two vs Restaurant Name - the average cost for two varias among different restaurants.
# - Average Cost for two vs City - The average cost for two varies across different cities.
# - Average Cost for two vs Locality - From Locality there is a wide range in the average cost for two.
# - Average Cost for two vs Cuisines - there is a wide range in the average cost for two for the different cuisines.
# - Average Cost for two vs Has Table booking - Restaurants which offer table booking tend to have a higher average cost for two compared to those that don't.
# - Average Cost for two vs Has Online delivery - Restaurants which don`t offer Online delivery have higher average cost for two compared to those that do.
# - Average Cost for two vs Is delivering now - Restaurants which don`t  deliver now have higher average cost for two compared to those that do.
# - Average Cost for two vs Switch to order menu - The restaurants don`t have switch to offer menu.
# - Average Cost for two vs Rating color - The restaurants with Dark Green rating tend to have higher average cost for two. As we see the color rating has significant impact on average cost for two.
# - Average Cost for two vs Rating text - The restaurants with Excellent rating tend to have higher average cost for two. As we see the color rating has significant impact on average cost for two.

# %%
# visualization of Numerical columns Vs Average Cost for two

plt.figure(figsize=(20,30), facecolor='white')
plotnumber=1

for col in num_columns:
    if plotnumber<=20:
        plt.subplot(10,2,plotnumber)
        ax= sns.scatterplot(x=col, y='Average Cost for two', data=df)
        plt.xlabel(col,fontsize=8)
    plotnumber+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - Average Cost for two vs Country Code - The majority of the data is concentrated in Country Code 1 (India), where the average cost for two is significantly higher than in other countries.
# - Average Cost for two vs Restaurant_ID - The average cost for two varies across different restaurants.
# - Average Cost for two vs Longitude - The average cost for two varies across different longitudes.
# - Average Cost for two vs Latitude - The average cost for two varies across different latitudes.
# - Average Cost for two vs Price range - The average cost for two varies across different price ranges but range 3 has the highest average cost for two.
# - Average Cost for two vs Aggregate rating - The higher aggregate rating has highter average cost for 2.
# - Average Cost for two across Votes - Some lower votes have significantly higher average costs.

# %%
# Visualization of Categorical column Vs Price Range

plt.figure(figsize=(20,25))
p=1

for i in cat_columns:
    if p<=20:
        plt.subplot(10,2,p)
        ax= sns.barplot(x=i, y='Price range',data=df)
        plt.xticks(fontsize=8)
    p+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - Price Range vs Country - The majority of the restaurants with lower price range are located in India. Those with the highest price range are in Qatar, Singapore and South Africa.
# - Price Range vs Currency - The Qatari Rial has highest price range. The lowest price range has the Indian Rupees.
# - Price Range vs Has Table booking - Restaurants without table booking (No) tend to have lower price ranges.
# - Price Range vs Has Online delivery - Restaurants offering online delivery (Yes) have higher price ranges.
# - Price Range vs Is delivering now - Restaurants offering delivery now (Yes) have higher price ranges.
# - Price Range vs Rating color - Restaurants which have higher price range are rated Dark Green Color.
# - Price Range vs Rating color - Restaurants which have higher price range are rated Excellent. Those with lower price range have rating Average or are not rated.

# %%
# visualization of Numerical columns Vs Price range

plt.figure(figsize=(20,30), facecolor='white')
plotnumber=1

for col in num_columns:
    if plotnumber<=20:
        plt.subplot(10,2,plotnumber)
        ax= sns.histplot(x=col, y='Price range', data=df)
        plt.xlabel(col,fontsize=8)
    plotnumber+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - Price rating vd Country code - The lowest price range 1 is found in Country Code 1 (India), indicating that most restaurants in India are generally more affordable.
# - Price range vs Votes - Lower value count is associated with higher price range.

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## Checking for outliers

# %%
# Checking for outliers only for numerical columns

plt.figure(figsize=(20,25))
pnum=1
for i in num_columns:
    if pnum<=30:
        plt.subplot(7,4,pnum)
        sns.boxplot(df[i],color='b')
        plt.xlabel(i)
    pnum+=1
plt.show()

# %% [markdown]
# There are outliers presented in all columns apart from Restaurant_ID.

# %% [markdown]
# ## Removing the outliers

# %%
from scipy.stats import zscore

outliers=df[num_columns]

z=np.abs(zscore(outliers))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  20,  102,  103, ..., 9549, 9550, 9550], dtype=int64), array([7, 7, 7, ..., 2, 0, 2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (9551, 22)

# %%
df_new.shape
# Out:
# (8565, 22)

# %% [markdown]
# 986 rows have been removed as outliers.

# %%
# Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df_new.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage: 10.323526332321222

# %%
df=df_new

# %% [markdown]
# ## Checking for skewness

# %%
df.skew()
# Out:
# Country Code            11.593933
# Restaurant ID            0.117936
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     3.718671
# Price range              1.029231
# Aggregate rating        -0.877262
# Votes                    3.653843
# dtype: float64

# %%
plt.figure(figsize=(20,25), facecolor='white')

plotnumber=1

for i in num_columns:   
    if plotnumber<=20:
        plt.subplot(5,4,plotnumber)
        sns.distplot(df[i],color='b')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# - In Country Code, Average Cost for two, Price range and votes the data is skewed to the right.
# - In Longitude, Latitude and Aggregate rating the data is skewed to the left.

# %% [markdown]
# ## Removing of skewness

# %%
df['Country Code'] = df['Country Code'].apply(lambda x: np.cbrt(x))
df['Average Cost for two'] = df['Average Cost for two'].apply(lambda x: np.cbrt(x))
df['Price range'] = df['Price range'].apply(lambda x: np.cbrt(x))
df['Votes'] = df['Votes'].apply(lambda x: np.cbrt(x))
df['Longitude'] = df['Longitude'].apply(lambda x: np.cbrt(x))
df['Latitude'] = df['Latitude'].apply(lambda x: np.cbrt(x))
df['Aggregate rating'] = df['Aggregate rating'].apply(lambda x: np.cbrt(x))

# %%
df.skew()
# Out:
# Country Code            11.542592
# Restaurant ID            0.117936
# Longitude               -3.765128
# Latitude                -3.596442
# Average Cost for two     1.044058
# Price range              0.614188
# Aggregate rating        -1.122575
# Votes                    0.761689
# dtype: float64

# %% [markdown]
# The skewness has been reduced.

# %%
#Dropping unnecessary columns

df.drop(columns=['Restaurant ID', 'Longitude','Latitude','Locality Verbose','Switch to order menu'],axis=1,inplace=True)

# %% [markdown]
# ## Encoding categorical data

# %%
# Encoding the categorical data into numerical using Original Encoder

from sklearn.preprocessing import OrdinalEncoder

OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1)) 
        
df.head()
# Out:
#    Country Code  Country  Restaurant Name  City  Address  Locality  Cuisines  \
# 0           1.0      0.0           2818.0   0.0   3828.0      13.0    1141.0
# 1           1.0      0.0           4658.0   0.0   3879.0      13.0    1141.0
# 2           1.0      0.0           6123.0   0.0   5417.0      13.0     938.0
# 3           1.0      0.0           1469.0   0.0     91.0     120.0    1255.0
# 4           1.0      0.0           4336.0   0.0   1047.0     120.0    1004.0
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0              9.472682       2.0                0.0                  0.0
# 1              8.879040       2.0                0.0                  0.0
# 2              7.937005       2.0                0.0                  0.0
# 3              7.368063       2.0                0.0                  0.0
# 4             10.000000       2.0                0.0                  0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8565 entries, 0 to 8862
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          8565 non-null   float64
#  1   Country               8565 non-null   float64
#  2   Restaurant Name       8565 non-null   float64
#  3   City                  8565 non-null   float64
#  4   Address               8565 non-null   float64
#  5   Locality              8565 non-null   float64
#  6   Cuisines              8565 non-null   float64
#  7   Average Cost for two  8565 non-null   float64
#  8   Currency              8565 non-null   float64
#  9   Has Table booking     8565 non-null   float64
#  10  Has Online delivery   8565 non-null   float64
#  11  Is delivering now     8565 non-null   float64
#  12  Price range           8565 non-null   float64
#  13  Aggregate rating      8565 non-null   float64
# ...

# %%
#Statistical summary of the data

df.describe()
# Out:
#        Country Code      Country  Restaurant Name         City      Address  \
# count   8565.000000  8565.000000      8565.000000  8565.000000  8565.000000
# mean       1.033379     0.021600      3221.416462    31.272504  4047.393812
# std        0.387891     0.261361      1890.117626     8.574998  2285.052237
# min        1.000000     0.000000         0.000000     0.000000     0.000000
# 25%        1.000000     0.000000      1577.000000    35.000000  2076.000000
# 50%        1.000000     0.000000      3165.000000    35.000000  4103.000000
# 75%        1.000000     0.000000      4841.000000    35.000000  6015.000000
# max        5.687734     4.000000      6572.000000    54.000000  7947.000000
#
#           Locality     Cuisines  Average Cost for two     Currency  \
# count  8565.000000  8565.000000           8565.000000  8565.000000
# mean    435.068768   723.488149              7.934866     1.997315
# std     210.281142   399.931587              2.064917     0.148533
# ...

# %% [markdown]
# ## Checking the correlation between the target variable and the independent variable

# %%
cor=df.corr()
cor
# Out:
#                       Country Code   Country  Restaurant Name      City  \
# Country Code              1.000000  0.966057         0.012263  0.022649
# Country                   0.966057  1.000000         0.007505  0.030770
# Restaurant Name           0.012263  0.007505         1.000000  0.008530
# City                      0.022649  0.030770         0.008530  1.000000
# Address                  -0.022569 -0.031028         0.001830 -0.095810
# Locality                 -0.029070 -0.031437         0.008658 -0.029670
# Cuisines                 -0.020453 -0.021027         0.060832  0.014873
# Average Cost for two     -0.025576 -0.050125         0.058540 -0.084334
# Currency                 -0.212243 -0.139876         0.000797 -0.134651
# Has Table booking         0.028481  0.010793         0.041460 -0.002165
# Has Online delivery      -0.053182 -0.051074         0.031504 -0.017478
# Is delivering now        -0.005433 -0.005218         0.013050 -0.023878
# ...

# %%
# Vusualizing the correlation

plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), linewidths=0.1,fmt='.1g',linecolor='black', annot = True, cmap = 'Blues')
plt.yticks(rotation=0);
plt.show()

# %%
# Correlation with the target Average Cost for two

cor_region=cor['Average Cost for two'].sort_values(ascending=False)
cor_region
# Out:
# Average Cost for two    1.000000
# Price range             0.861018
# Has Table booking       0.617158
# Votes                   0.514683
# Aggregate rating        0.359413
# Has Online delivery     0.164124
# Rating text             0.065770
# Restaurant Name         0.058540
# Is delivering now       0.024454
# Address                 0.017810
# Cuisines                0.002598
# Country Code           -0.025576
# Country                -0.050125
# Rating color           -0.064963
# Currency               -0.065826
# Locality               -0.073840
# City                   -0.084334
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# - Possitive correlation with Average Cost for two - Price range (0.86), Has Table booking (0.62), Votes (0.51) and Aggregate rating (0.36).
# - Negative correlation with Average Cost for two - City (-0.8), Locality (-0.74), Country (-0.05), Rating color (-0.065), Currency (-0.66)

# %% [markdown]
# ## Visualizing correlation with the target  Average Cost for two

# %%
plt.figure(figsize=(25,10))

df_new.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='b')
plt.xlabel('Feature', fontsize=12)
plt.ylabel('Target', fontsize=12)
plt.show()

# %%
# Correlation with the target Price range

cor_region=cor['Price range'].sort_values(ascending=False)
cor_region
# Out:
# Price range             1.000000
# Average Cost for two    0.861018
# Has Table booking       0.546612
# Votes                   0.529663
# Aggregate rating        0.367788
# Country Code            0.163455
# Has Online delivery     0.162643
# Country                 0.159307
# Rating text             0.082879
# Restaurant Name         0.065204
# Is delivering now       0.024281
# Cuisines                0.023799
# Address                -0.027711
# Currency               -0.028523
# Rating color           -0.068746
# Locality               -0.103064
# City                   -0.115992
# Name: Price range, dtype: float64

# %% [markdown]
# - Possitive correlation with Price range - Average Cost for two (0.86), Has Table booking (0.55), Votes (0.53), Aggregate rating (0.37)
# - Negative correlation with Price range - Rating color (-0.067), Locality (-0.10), City (-0.12)

# %% [markdown]
# ## Visualizing correlation with the target Price range

# %%
plt.figure(figsize=(25,10))

df_new.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar',color='b')
plt.xlabel('Feature', fontsize=12)
plt.ylabel('Target', fontsize=12)
plt.show()

# %% [markdown]
# # Separating features and label

# %%
x=df.drop(['Average Cost for two'],axis=1)
y=df['Average Cost for two']

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    Country Code   Country  Restaurant Name      City   Address  Locality  \
# 0     -0.086058 -0.082647        -0.213447 -3.647153 -0.096018 -2.007281
# 1     -0.086058 -0.082647         0.760094 -3.647153 -0.073698 -2.007281
# 2     -0.086058 -0.082647         1.535223 -3.647153  0.599411 -2.007281
# 3     -0.086058 -0.082647        -0.927201 -3.647153 -1.731525 -1.498409
# 4     -0.086058 -0.082647         0.589724 -3.647153 -1.313129 -1.498409
#
#    Cuisines  Currency  Has Table booking  Has Online delivery  \
# 0  1.044019   0.01808          -0.377031            -0.617978
# 1  1.044019   0.01808          -0.377031            -0.617978
# 2  0.536403   0.01808          -0.377031            -0.617978
# 3  1.329085   0.01808          -0.377031            -0.617978
# 4  0.701441   0.01808          -0.377031            -0.617978
#
#    Is delivering now  Price range  Aggregate rating  Rating color  \
# 0          -0.063131     1.484107          0.701990      1.393658
# ...

# %% [markdown]
# # Checking Variance Inflation Factor VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values             Features
# 0    76.680077         Country Code
# 1     9.865401              Country
# 2     3.938743      Restaurant Name
# 3    13.729847                 City
# 4     4.352466              Address
# 5     5.499460             Locality
# 6     4.353195             Cuisines
# 7    84.046493             Currency
# 8     1.636057    Has Table booking
# 9     1.615699  Has Online delivery
# 10    1.018723    Is delivering now
# 11   67.585909          Price range
# 12   14.128314     Aggregate rating
# 13    7.210573         Rating color
# 14    3.582942          Rating text
# 15    9.169539                Votes

# %% [markdown]
# By checking the VIF values we can find the features causing multicollineraty problem.
#
# The VIF in Country Code, injury_claim, City, Currency, Price range and Aggregate rating. That means that there is multicollineraty between these features and the other features.
#
# We will drop one of the columns to see if the same issue still exist.

# %%
x=x.drop('Currency',axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values             Features
# 0    61.557296         Country Code
# 1     7.633694              Country
# 2     3.927671      Restaurant Name
# 3    13.310540                 City
# 4     4.328367              Address
# 5     5.434507             Locality
# 6     4.287982             Cuisines
# 7     1.525104    Has Table booking
# 8     1.615677  Has Online delivery
# 9     1.018610    Is delivering now
# 10   53.808244          Price range
# 11   13.742508     Aggregate rating
# 12    6.886423         Rating color
# 13    3.564366          Rating text
# 14    8.882316                Votes

# %% [markdown]
# We have to drop one more columns as we still have high VIF.

# %%
x=x.drop('Country Code',axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values             Features
# 0     1.037232              Country
# 1     3.898344      Restaurant Name
# 2    11.764948                 City
# 3     4.235552              Address
# 4     5.266320             Locality
# 5     4.219500             Cuisines
# 6     1.435627    Has Table booking
# 7     1.612586  Has Online delivery
# 8     1.018552    Is delivering now
# 9    34.592672          Price range
# 10   13.425564     Aggregate rating
# 11    6.780024         Rating color
# 12    3.513775          Rating text
# 13    8.760198                Votes

# %% [markdown]
# # Machine learning - Average Cost for two

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## Finding the best random state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.8332019795068368 on random state 172

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=maxRS)

# %% [markdown]
# ## Linear Regression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.8059817213317678

# %%
lrpred=lr.predict(x_test)

# %%
print('R2_score: ', r2_score(y_test,lrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,lrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,lrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,lrpred)))
# Out:
# R2_score:  0.8149396944388119
# Mean Absolute Error:  0.6758064174807769
# Mean Squared Error:  0.8170195510062568
# Root Mean Squared Error:  0.9038913380524546

# %% [markdown]
# ## Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtrpred=dtr.predict(x_test)

# %%
dtr.score(x_train, y_train)
# Out:
# 1.0

# %%
print('R2_score: ', r2_score(y_test,dtrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,dtrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,dtrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,dtrpred)))
# Out:
# R2_score:  0.7737565367001483
# Mean Absolute Error:  0.6853698218185132
# Mean Squared Error:  0.9988383637582846
# Root Mean Squared Error:  0.9994190131062569

# %% [markdown]
# ## Support Vector Regressor

# %%
svr=SVR()
svr.fit(x_train,y_train)
svrpred=svr.predict(x_test)

# %%
svr.score(x_train, y_train)
# Out:
# 0.004085840589868495

# %%
print('R2_score: ', r2_score(y_test,svrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,svrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,svrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,svrpred)))
# Out:
# R2_score:  -0.011053829346105104
# Mean Absolute Error:  1.5287447708748196
# Mean Squared Error:  4.463684112000921
# Root Mean Squared Error:  2.112743266940146

# %% [markdown]
# ## Random Forest Regressor

# %%
rfr=RandomForestRegressor(n_estimators=200, random_state=maxRS)
rfr.fit(x_train, y_train)
rfrpred= rfr.predict(x_test)

# %%
rfr.score(x_train, y_train)
# Out:
# 0.9830076890393521

# %%
print('R2_score: ', r2_score(y_test,rfrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,rfrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,rfrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,rfrpred)))
# Out:
# R2_score:  0.8786679098877785
# Mean Absolute Error:  0.5239104095943057
# Mean Squared Error:  0.5356669518378236
# Root Mean Squared Error:  0.731892718803667

# %% [markdown]
# ## AdaBoost Regressor

# %%
abr=AdaBoostRegressor()
abr.fit(x_train,y_train)
abrpred=abr.predict(x_test)

# %%
abr.score(x_train, y_train)
# Out:
# 0.8073271100640181

# %%
print('R2_score: ', r2_score(y_test,abrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,abrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,abrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,abrpred)))
# Out:
# R2_score:  0.7970586959730267
# Mean Absolute Error:  0.7251225477269782
# Mean Squared Error:  0.895962062712145
# Root Mean Squared Error:  0.9465527257961623

# %% [markdown]
# ## Ridge

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
ridgepred=ridge.predict(x_test)

# %%
ridge.score(x_train, y_train)
# Out:
# 0.8059568769375823

# %%
print('R2_score: ', r2_score(y_test,ridgepred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,ridgepred))
print('Mean Squared Error: ', mean_squared_error(y_test,ridgepred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,ridgepred)))
# Out:
# R2_score:  0.8148915182146903
# Mean Absolute Error:  0.6745712904869594
# Mean Squared Error:  0.8172322433871623
# Root Mean Squared Error:  0.9040089841296723

# %% [markdown]
# ## Lasso

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
lassopred=lasso.predict(x_test)

# %%
lasso.score(x_train, y_train)
# Out:
# 0.2343923667924559

# %%
print('R2_score: ', r2_score(y_test, lassopred))
print('Mean Absolute Error: ', mean_absolute_error(y_test, lassopred))
print('Mean Squared Error: ', mean_squared_error(y_test, lassopred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, lassopred)))
# Out:
# R2_score:  0.2154264928799069
# Mean Absolute Error:  1.347416570567648
# Mean Squared Error:  3.4638000438549965
# Root Mean Squared Error:  1.861128701582724

# %% [markdown]
# ## KNeighbors Regressor

# %%
knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
knrpred=knr.predict(x_test)

# %%
knr.score(x_train, y_train)
# Out:
# 0.3129937402637123

# %%
print('R2_score: ', r2_score(y_test, knrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test, knrpred))
print('Mean Squared Error: ', mean_squared_error(y_test, knrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, knrpred)))
# Out:
# R2_score:  0.027252306712702845
# Mean Absolute Error:  1.5560442013658786
# Mean Squared Error:  4.294567012638931
# Root Mean Squared Error:  2.07233371169774

# %% [markdown]
# ## GradientBoosting Regressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbrpred=gbr.predict(x_test)

# %%
gbr.score(x_train, y_train)
# Out:
# 0.888984546335867

# %%
print('R2_score: ', r2_score(y_test, gbrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test, gbrpred))
print('Mean Squared Error: ', mean_squared_error(y_test, gbrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, gbrpred)))
# Out:
# R2_score:  0.8719908247421521
# Mean Absolute Error:  0.5575510064017069
# Mean Squared Error:  0.5651454998774329
# Root Mean Squared Error:  0.7517615977671598

# %% [markdown]
# Random Forest Regressor and GradientBoosting areour best models as they have high R2 score and High accuracy.

# %% [markdown]
# ## Hyper Parameter Tuning for Average cost for two target

# %%
from sklearn.model_selection import GridSearchCV

# %%
# for RandomForest

param1 = {
    'n_estimators': [10, 50, 100],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
GSCV_1=GridSearchCV(RandomForestRegressor(),param1,cv=5)

# %%
GSCV_1.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
GSCV_1.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
Final_model_regression_rf=RandomForestRegressor(n_estimators=100, criterion= 'squared_error', max_depth=5, min_samples_split=2, min_samples_leaf= 1)
Final_model_regression_rf.fit(x_train, y_train)
prediction=Final_model_regression_rf.predict(x_test)

print("R2 score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# R2 score: 0.8537947505718493
# Mean Absolute Error: 0.5963178835158515
# Mean Squared Error: 0.6454790338766074
# Root Mean Squared Error: 0.8034170983222895

# %%
# for GradientBoosting

param2={'n_estimators':[40, 60, 80, 100],
             'criterion':['squared_error', 'friedman_mse'],
             'max_depth':[2, 3, 10, 20,30],
             'min_samples_leaf':[1, 5, 10, 15, 20],
             'learning_rate':[0.0, 0.1, 0.5,1.0, 2.0]}

# %%
GSCV_1_gb=GridSearchCV(GradientBoostingRegressor(),param2,cv=5)

# %%
GSCV_1_gb.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'learning_rate': [0.0, 0.1, 0.5, 1.0, 2.0],
#                          'max_depth': [2, 3, 10, 20, 30],
#                          'min_samples_leaf': [1, 5, 10, 15, 20],
#                          'n_estimators': [40, 60, 80, 100]})

# %%
GSCV_1.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
Final_model_regression_gb=GradientBoostingRegressor(n_estimators=100, criterion= 'squared_error', max_depth=5, min_samples_split=2, min_samples_leaf= 1)
Final_model_regression_gb.fit(x_train, y_train)
prediction=Final_model_regression_gb.predict(x_test)

print("R2 score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# R2 score: 0.8818288442713501
# Mean Absolute Error: 0.530715270142367
# Mean Squared Error: 0.5217117971492238
# Root Mean Squared Error: 0.7222961976566288

# %% [markdown]
# # Saving the regression model

# %%
import joblib

joblib.dump(rfr, 'zomato-rfr.pkl.obj')
# Out:
# ['zomato-rfr.pkl.obj']

# %%
joblib.dump(gbr, 'rainfall-gbr.pkl.obj')
# Out:
# ['rainfall-gbr.pkl.obj']

# %% [markdown]
# # Machine Learning for Price range

# %% [markdown]
# ## Separating features and label

# %%
x1=df.drop(['Price range'],axis=1)
y1=df['Price range']

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
scaler=StandardScaler()

x1=pd.DataFrame(scaler.fit_transform(x1), columns=x1.columns)
x1.head()
# Out:
#    Country Code   Country  Restaurant Name      City   Address  Locality  \
# 0     -0.086058 -0.082647        -0.213447 -3.647153 -0.096018 -2.007281
# 1     -0.086058 -0.082647         0.760094 -3.647153 -0.073698 -2.007281
# 2     -0.086058 -0.082647         1.535223 -3.647153  0.599411 -2.007281
# 3     -0.086058 -0.082647        -0.927201 -3.647153 -1.731525 -1.498409
# 4     -0.086058 -0.082647         0.589724 -3.647153 -1.313129 -1.498409
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  1.044019              0.744779   0.01808          -0.377031
# 1  1.044019              0.457272   0.01808          -0.377031
# 2  0.536403              0.001036   0.01808          -0.377031
# 3  1.329085             -0.274508   0.01808          -0.377031
# 4  0.701441              1.000164   0.01808          -0.377031
#
#    Has Online delivery  Is delivering now  Aggregate rating  Rating color  \
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor VIF

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features']=x1.columns

vif
# Out:
#     VIF values              Features
# 0    16.841793          Country Code
# 1    16.374334               Country
# 2     1.009024       Restaurant Name
# 3     1.064753                  City
# 4     1.061045               Address
# 5     1.055680              Locality
# 6     1.020953              Cuisines
# 7     2.028812  Average Cost for two
# 8     1.154319              Currency
# 9     1.648062     Has Table booking
# 10    1.169144   Has Online delivery
# 11    1.014891     Is delivering now
# 12    3.612833      Aggregate rating
# 13    1.257262          Rating color
# 14    1.762948           Rating text
# 15    3.180605                 Votes

# %%
x1=x1.drop('Country Code',axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features']=x1.columns

vif
# Out:
#     VIF values              Features
# 0     1.109156               Country
# 1     4.047100       Restaurant Name
# 2    11.871345                  City
# 3     4.733327               Address
# 4     5.477590              Locality
# 5     4.863998              Cuisines
# 6    30.453250  Average Cost for two
# 7    31.396416              Currency
# 8     2.895921     Has Table booking
# 9     1.635522   Has Online delivery
# 10    1.019684     Is delivering now
# 11   18.880433      Aggregate rating
# 12    6.147082          Rating color
# 13    3.481850           Rating text
# 14   11.497696                 Votes

# %%
y1.value_counts()
# Out:
# 0    4289
# 1    2827
# 2    1052
# 3     397
# Name: Price range, dtype: int64

# %%
# Initiate over-sampler
sm=SMOTE()

x1,y1=sm.fit_resample(x1,y1)

# Checking Value count after applying SMOTE
y1.value_counts()
# Out:
# 2    4289
# 1    4289
# 3    4289
# 0    4289
# Name: Price range, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
maxAccu1=0
maxRS1=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    RFR1=RandomForestClassifier()
    RFR1.fit(x1_train,y1_train)
    pred1=RFR1.predict(x1_test)
    acc1=accuracy_score(y1_test,pred1)
    if acc1>maxAccu:
        maxAccu1=acc1
        maxRS1=i
print("Best accuracy is",maxAccu1,"at random_state",maxRS1)
# Out:
# Best accuracy is 0.9809597823975131 at random_state 199

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.3, random_state=maxRS1)

# %% [markdown]
# ## Random Forest Classifier

# %%
rfc=RandomForestClassifier(n_estimators=200, random_state=maxRS1)

# %%
rfc.fit(x1_train, y1_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=199)

# %%
rfcpred= rfc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, rfcpred))
# Out:
# [[1313    1    0    0]
#  [  14 1272   15    0]
#  [   0   11 1245   22]
#  [   0    0   29 1225]]

# %%
print(classification_report(y1_test,rfcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1314
#            1       0.99      0.98      0.98      1301
#            2       0.97      0.97      0.97      1278
#            3       0.98      0.98      0.98      1254
#
#     accuracy                           0.98      5147
#    macro avg       0.98      0.98      0.98      5147
# weighted avg       0.98      0.98      0.98      5147

# %%
print('Accuracy Score of RFC: ', accuracy_score(y1_test, rfcpred))
# Out:
# Accuracy Score of RFC:  0.9821255100058286

# %% [markdown]
# ## GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(x1_train,y1_train)
# Out:
# GaussianNB()

# %%
gnbpred= rfc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, gnbpred))
# Out:
# [[1313    1    0    0]
#  [  14 1272   15    0]
#  [   0   11 1245   22]
#  [   0    0   29 1225]]

# %%
print(classification_report(y1_test,gnbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1314
#            1       0.99      0.98      0.98      1301
#            2       0.97      0.97      0.97      1278
#            3       0.98      0.98      0.98      1254
#
#     accuracy                           0.98      5147
#    macro avg       0.98      0.98      0.98      5147
# weighted avg       0.98      0.98      0.98      5147

# %%
print('Accuracy Score of GaussianNB: ', accuracy_score(y1_test, gnbpred))
# Out:
# Accuracy Score of GaussianNB:  0.9821255100058286

# %% [markdown]
# ## K-Neighbors Classifier

# %%
knc=KNeighborsClassifier(n_neighbors=13)

# %%
knc.fit(x1_train,y1_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
kncpred=knc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, kncpred))
# Out:
# [[ 549  284  277  204]
#  [ 281  543  289  188]
#  [ 101  165  844  168]
#  [  35   65   95 1059]]

# %%
print(classification_report(y1_test,kncpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.42      0.48      1314
#            1       0.51      0.42      0.46      1301
#            2       0.56      0.66      0.61      1278
#            3       0.65      0.84      0.74      1254
#
#     accuracy                           0.58      5147
#    macro avg       0.57      0.59      0.57      5147
# weighted avg       0.57      0.58      0.57      5147

# %%
print('Accuracy Score of K-Neighbors: ', accuracy_score(y1_test, kncpred))
# Out:
# Accuracy Score of K-Neighbors:  0.5818923644841655

# %% [markdown]
# ## Logistic regression

# %%
LR=LogisticRegression()

# %%
LR.fit(x1_train,y1_train)
# Out:
# LogisticRegression()

# %%
LRpred=LR.predict(x1_test)

# %%
print(confusion_matrix(y1_test, LRpred))
# Out:
# [[955 196  81  82]
#  [466 309 306 220]
#  [ 93 157 686 342]
#  [ 38  50 475 691]]

# %%
print(classification_report(y1_test,LRpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67      1314
#            1       0.43      0.24      0.31      1301
#            2       0.44      0.54      0.49      1278
#            3       0.52      0.55      0.53      1254
#
#     accuracy                           0.51      5147
#    macro avg       0.50      0.51      0.50      5147
# weighted avg       0.50      0.51      0.50      5147

# %%
print('Accuracy Score of Logistic Regression: ', accuracy_score(y1_test, LRpred))
# Out:
# Accuracy Score of Logistic Regression:  0.5131144355935496

# %% [markdown]
# ## Decision Tree

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x1_train,y1_train)
# Out:
# DecisionTreeClassifier()

# %%
dtcpred=dtc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, dtcpred))
# Out:
# [[1310    4    0    0]
#  [  10 1261   30    0]
#  [   0   16 1217   45]
#  [   0    0   25 1229]]

# %%
print(classification_report(y1_test,dtcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1314
#            1       0.98      0.97      0.98      1301
#            2       0.96      0.95      0.95      1278
#            3       0.96      0.98      0.97      1254
#
#     accuracy                           0.97      5147
#    macro avg       0.97      0.97      0.97      5147
# weighted avg       0.97      0.97      0.97      5147

# %%
print('Accuracy Score of Decision Tree Classifier: ', accuracy_score(y1_test, dtcpred))
# Out:
# Accuracy Score of Decision Tree Classifier:  0.974742568486497

# %% [markdown]
# ## Support Vector Classifier

# %%
svc=SVC()

# %%
svc.fit(x1_train,y1_train)
# Out:
# SVC()

# %%
svcpred=svc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, svcpred))
# Out:
# [[300 204 401 409]
#  [219 250 449 383]
#  [138 160 632 348]
#  [104 103 438 609]]

# %%
print(classification_report(y1_test,svcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.23      0.29      1314
#            1       0.35      0.19      0.25      1301
#            2       0.33      0.49      0.40      1278
#            3       0.35      0.49      0.41      1254
#
#     accuracy                           0.35      5147
#    macro avg       0.36      0.35      0.33      5147
# weighted avg       0.36      0.35      0.33      5147

# %%
print('Accuracy Score of SVC: ', accuracy_score(y1_test, svcpred))
# Out:
# Accuracy Score of SVC:  0.3479696910821838

# %% [markdown]
# ## AdaBoostClassifier

# %%
abc=AdaBoostClassifier()

# %%
abc.fit(x1_train,y1_train)
# Out:
# AdaBoostClassifier()

# %%
abcpred=abc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, svcpred))
# Out:
# [[300 204 401 409]
#  [219 250 449 383]
#  [138 160 632 348]
#  [104 103 438 609]]

# %%
print(classification_report(y1_test,abcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1314
#            1       0.36      0.98      0.53      1301
#            2       0.20      0.03      0.05      1278
#            3       0.69      0.03      0.06      1254
#
#     accuracy                           0.52      5147
#    macro avg       0.56      0.51      0.41      5147
# weighted avg       0.56      0.52      0.41      5147

# %%
print('Accuracy Score of ABC: ', accuracy_score(y1_test, abcpred))
# Out:
# Accuracy Score of ABC:  0.5181659218962502

# %% [markdown]
# ## GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()

# %%
gb.fit(x1_train,y1_train)
# Out:
# GradientBoostingClassifier()

# %%
gbpred=gb.predict(x1_test)

# %%
print(confusion_matrix(y1_test, gbpred))
# Out:
# [[1314    0    0    0]
#  [  12 1280    9    0]
#  [   0   27 1218   33]
#  [   0    0   27 1227]]

# %%
print(classification_report(y1_test,gbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1314
#            1       0.98      0.98      0.98      1301
#            2       0.97      0.95      0.96      1278
#            3       0.97      0.98      0.98      1254
#
#     accuracy                           0.98      5147
#    macro avg       0.98      0.98      0.98      5147
# weighted avg       0.98      0.98      0.98      5147

# %%
print('Accuracy Score of GBC: ', accuracy_score(y1_test, gbpred))
# Out:
# Accuracy Score of GBC:  0.9790169030503206

# %% [markdown]
# ## BaggingClassifier

# %%
bc=BaggingClassifier()

# %%
bc.fit(x1_train,y1_train)
# Out:
# BaggingClassifier()

# %%
bcpred=bc.predict(x1_test)

# %%
print(confusion_matrix(y1_test, bcpred))
# Out:
# [[1312    2    0    0]
#  [  12 1278   11    0]
#  [   0   21 1230   27]
#  [   0    0   26 1228]]

# %%
print(classification_report(y1_test,bcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1314
#            1       0.98      0.98      0.98      1301
#            2       0.97      0.96      0.97      1278
#            3       0.98      0.98      0.98      1254
#
#     accuracy                           0.98      5147
#    macro avg       0.98      0.98      0.98      5147
# weighted avg       0.98      0.98      0.98      5147

# %%
print('Accuracy Score of BC: ', accuracy_score(y1_test, bcpred))
# Out:
# Accuracy Score of BC:  0.9807654944627938

# %% [markdown]
# ## Extra Trees Classifier

# %%
et=ExtraTreesClassifier()

# %%
et.fit(x1_train,y1_train)
# Out:
# ExtraTreesClassifier()

# %%
etpred=et.predict(x1_test)

# %%
print(confusion_matrix(y1_test, etpred))
# Out:
# [[1304   10    0    0]
#  [  11 1259   31    0]
#  [   0   20 1242   16]
#  [   0    0   16 1238]]

# %%
print(classification_report(y1_test,etpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1314
#            1       0.98      0.97      0.97      1301
#            2       0.96      0.97      0.97      1278
#            3       0.99      0.99      0.99      1254
#
#     accuracy                           0.98      5147
#    macro avg       0.98      0.98      0.98      5147
# weighted avg       0.98      0.98      0.98      5147

# %%
print('Accuracy Score of ETC: ', accuracy_score(y1_test, etpred))
# Out:
# Accuracy Score of ETC:  0.9797940547891976

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# CV score for RandomForest Classifier

score=cross_val_score(rfc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, rfcpred) - score.mean())
# Out:
# Score:  [0.92977855 0.97784902 0.98630137 0.97784902 0.97784902]
# Mean Score:  0.9699253990932803
# Std deviation:  0.020338598788736485
# Difference between Accuracy score and CV Score is   0.012200110912548245

# %%
# CV score for Support Vector Classifier

score=cross_val_score(svc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, svcpred) - score.mean())
# Out:
# Score:  [0.33712121 0.25823375 0.33430487 0.36665695 0.33692801]
# Mean Score:  0.32664895825053214
# Std deviation:  0.03620834162784312
# Difference between Accuracy score and CV Score is   0.021320732831651645

# %%
# CV score for DecisionTree Classifier

score=cross_val_score(dtc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, dtcpred) - score.mean())
# Out:
# Score:  [0.76252914 0.97493442 0.97959778 0.96181871 0.96181871]
# Mean Score:  0.9281397534749327
# Std deviation:  0.08310606539091393
# Difference between Accuracy score and CV Score is   0.04660281501156427

# %%
# CV score for K-Neighbors Classifier

score=cross_val_score(knc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, kncpred) - score.mean())
# Out:
# Score:  [0.54895105 0.54707082 0.60040804 0.63217721 0.64849898]
# Mean Score:  0.5954212211571581
# Std deviation:  0.04169018388453557
# Difference between Accuracy score and CV Score is   -0.01352885667299264

# %%
# CV score for GNB Classifier

score=cross_val_score(gnb,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, gnbpred) - score.mean())
# Out:
# Score:  [0.65355478 0.81404838 0.80851064 0.8359079  0.83386768]
# Mean Score:  0.789177874976476
# Std deviation:  0.06865390837471566
# Difference between Accuracy score and CV Score is   0.19294763502935264

# %%
# CV score for AB Classifier

score=cross_val_score(abc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, abcpred) - score.mean())
# Out:
# Score:  [0.5201049  0.51471874 0.51588458 0.50859808 0.51326144]
# Mean Score:  0.5145135467854792
# Std deviation:  0.0037348515293237597
# Difference between Accuracy score and CV Score is   0.003652375110770989

# %%
# CV score for GB Classifier

score=cross_val_score(gb,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, gbpred) - score.mean())
# Out:
# Score:  [0.76806527 0.97406004 0.98105509 0.96648208 0.97347712]
# Mean Score:  0.9326279180840533
# Std deviation:  0.08241048288449333
# Difference between Accuracy score and CV Score is   0.04638898496626731

# %%
# CV score for Bagging Classifier

score=cross_val_score(bc,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, bcpred) - score.mean())
# Out:
# Score:  [0.78175991 0.98134655 0.98192947 0.96356747 0.97406004]
# Mean Score:  0.9365326866857033
# Std deviation:  0.07766974316899743
# Difference between Accuracy score and CV Score is   0.04423280777709049

# %%
# CV score for Extra Tree Classifier

score=cross_val_score(et,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, etpred) - score.mean())
# Out:
# Score:  [0.79283217 0.96444185 0.9685223  0.97551734 0.94812008]
# Mean Score:  0.9298867483434666
# Std deviation:  0.06911631421084731
# Difference between Accuracy score and CV Score is   0.04990730644573094

# %%
# CV score for Logistic Regression

score=cross_val_score(LR,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and CV Score is  ', accuracy_score(y1_test, LRpred) - score.mean())
# Out:
# Score:  [0.28875291 0.34596328 0.54852813 0.54707082 0.52346255]
# Mean Score:  0.4507555375742493
# Std deviation:  0.11076885037782606
# Difference between Accuracy score and CV Score is   0.062358898019300335

# %% [markdown]
# RFC, GNB, GBC, BC and ET have high accuracy score 0.98. Random Forest has also high CV score (0.97) suggests that the model's performance is relatively consistent during cross-validation, and low difference between the accuracy score and cross validation score 0.01. Randon Forest Classifier is our best model.

# %% [markdown]
# ## Hyper Parameter Tuning for RandomForest Classifier

# %%
param_rf={'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']}

# %%
GSCV_rf=GridSearchCV(RandomForestClassifier(),param_rf,cv=5)

# %%
GSCV_rf.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'n_estimators': [50, 100, 200]})

# %%
GSCV_rf.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'n_estimators': 200}

# %%
Final_model_rf=RandomForestClassifier(criterion= 'entropy', max_depth= None, max_features= 'sqrt', min_samples_leaf= 1, n_estimators= 200)
Final_model_rf.fit(x1_train, y1_train)
prediction1=Final_model_rf.predict(x1_test)

print("R2 score:",r2_score(y1_test,prediction1))
print("Mean Absolute Error:",mean_absolute_error(y1_test,prediction1))
print("Mean Squared Error:",mean_squared_error(y1_test,prediction1))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y1_test,prediction1)))
print("Accuracy score", accuracy_score(y1_test, prediction1) *100)
# Out:
# R2 score: 0.9872289030922434
# Mean Absolute Error: 0.015931610646978824
# Mean Squared Error: 0.015931610646978824
# Root Mean Squared Error: 0.12622048426059387
# Accuracy score 98.40683893530212

# %% [markdown]
# # ROC-AUC Curve

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
fpr, tpr, thresholds =roc_curve(y1_test, prediction1, pos_label=1)

# %%
roc_auc=metrics.auc(fpr,tpr)

# %%
#ROC-AUC Curve for Random Forest Classifier

display_rf=metrics.RocCurveDisplay(fpr = fpr, tpr=tpr, roc_auc=roc_auc,estimator_name=Final_model_rf)

# %%
display_rf.plot()

# %% [markdown]
# # Saving the classification model

# %%
import joblib

joblib.dump(Final_model_rf,'Zomato-classification.pkl')
# Out:
# ['Zomato-classification.pkl']
