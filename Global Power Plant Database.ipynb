# %% [markdown]
# # Global Power Plant Database

# %% [markdown]
# ## Project Description

# %% [markdown]
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [markdown]
# ### Key attributes of the database

# %% [markdown]
# The database includes the following indicators:
#
# •
#
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# •	`country_long` (text): longer form of the country designation
#
# •	`name` (text): name or title of the power plant, generally in Romanized form
#
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
#
# •	`capacity_mw` (number): electrical generating capacity in megawatts
#
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
#
# •	`other_fuel1` (text): energy source used in electricity generation or export
#
# •	`other_fuel2` (text): energy source used in electricity generation or export
#
# •	`other_fuel3` (text): energy source used in electricity generation or export
#
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
#
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
#
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# •	`url` (text): web document corresponding to the `source` field
#
# •	`geolocation_source` (text): attribution for geolocation information
#
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# •	`year_of_capacity_data` (number): year the capacity information was reported
#
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
#
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
#
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
#
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
#
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017

# %% [markdown]
# •	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
#
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
#
# •	`generation_data_source` (text): attribution for the reported generation information
#
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
#
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
#
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
#
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
#
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
#
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
#
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
#
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
#
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
#
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
#
#
# Fuel Type Aggregation
#
# We define the "Fuel Type" attribute of our database based on common fuel categories.
#
# ### Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw

# %% [markdown]
# ## Dataset Link-
#
# •	https://github.com/wri/global-power-plant-database/blob/master/source_databases_csv/database_IND.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
df=pd.read_csv('database_IND.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
#Checking the dimentions of the dataset

df.shape
# Out:
# (907, 27)

# %% [markdown]
# We have 907 rows and 27 columns.

# %%
#Checking the columns of the dataset

df.columns.to_list()
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'capacity_mw',
#  'latitude',
#  'longitude',
#  'primary_fuel',
#  'other_fuel1',
#  'other_fuel2',
#  'other_fuel3',
#  'commissioning_year',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'wepp_id',
#  'year_of_capacity_data',
#  'generation_gwh_2013',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'generation_gwh_2019',
#  'generation_data_source',
#  'estimated_generation_gwh']

# %%
# Checking the types of columns

df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# There are two different data types in the dataset - float64 and object.

# %%
# Checking the null values

df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# As we can see there are null values in that dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
# Using heatmap to visualize the null values.

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Checking for diblicate values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no dublicate values.

# %%
#Checking for unique values of each column.

for i in df.columns:
    print(df[i].unique())
    print("\n")
# Out:
# ['IND']
#
#
# ['India']
#
#
# ['ACME Solar Tower' 'ADITYA CEMENT WORKS' 'AES Saurashtra Windfarms'
#  'AGARTALA GT' 'AKALTARA TPP' 'AKRIMOTA LIG' 'ALIYAR' 'ALLAIN DUHANGAN'
#  'ALMATTI DAM' 'AMAR KANTAK' 'AMARAVATI TPP' 'ANANDPUR SAHIB ST-I&II'
#  'ANAPARA "C"' 'ANDHRA' 'ANOOPGARH ST I&II' 'ANPARA' 'ANTA GT' 'ANUPPUR'
#  'ANUPUR TPP' 'ARVINDNAGAR SUGAR' 'ASHOKNAGAR MILL' 'ATHANI SUGAR'
#  'AURAIYA GT' 'AVANTHA BHANDAR TPP' 'AWARPUR CEMENT PLANT' 'Abhijeet'
#  'Amarsar Solar Power Plant' 'Anabura Wind Farm'
#  'Ananthapur - Meil Solar Power Plant' 'Andrha Lake Wind Farm'
#  'Anikkadavu Wind Farm' 'Arasinagundi Wind Farm'
#  'Askandra - DREPL Solar Power Plant'
#  'Askandra - Electromech Maritech Solar Power Plant'
#  'Askandra - Finehope Solar Power Plant'
#  'Askandra - Khaya Solar Power Plant'
#  'Askandra - Newton Solar Power Plant'
#  'Askandra - Saidham Solar Power Plant'
#  'Askandra - Vasavi Solar Power Plant' 'BADARPUR' 'BAGALKOT ICP'
# ...

# %%
#Checking the number of unique values in each column

df.nunique().to_frame("Number of unique values")
# Out:
#                           Number of unique values
# country                                         1
# country_long                                    1
# name                                          907
# gppd_idnr                                     907
# capacity_mw                                   361
# latitude                                      836
# longitude                                     827
# primary_fuel                                    8
# other_fuel1                                     3
# other_fuel2                                     1
# other_fuel3                                     0
# commissioning_year                             73
# owner                                         280
# source                                        191
# url                                           304
# geolocation_source                              3
# wepp_id                                         0
# year_of_capacity_data                           1
# ...

# %%
#Checking the value counts of each column.

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# IND    907
# Name: country, dtype: int64
#
#
# India    907
# Name: country_long, dtype: int64
#
#
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64
#
#
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# 19.0004    3
# 24.1917    3
# 24.8747    2
# ...

# %%
# Dropping the columns that containing mostly NuN Values and those which has only 1 Unique values.

df=df.drop('country',axis=1)
df=df.drop('country_long',axis=1)
df=df.drop('other_fuel3',axis=1)
df=df.drop('wepp_id',axis=1)
df=df.drop('estimated_generation_gwh',axis=1)
df=df.drop('generation_gwh_2019',axis=1)
df=df.drop('generation_gwh_2013',axis=1)
df=df.drop('other_fuel2',axis=1)
df=df.drop('year_of_capacity_data',axis=1)
df=df.drop('owner',axis=1)
df=df.drop('generation_data_source',axis=1)
df=df.drop('name',axis=1)
df=df.drop('gppd_idnr',axis=1)
df=df.drop('url',axis=1)

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0          2.5   28.1839    73.2407        Solar         NaN
# 1         98.0   24.7663    74.6090         Coal         NaN
# 2         39.2   21.9038    69.3732         Wind         NaN
# 3        135.0   23.8712    91.3602          Gas         NaN
# 4       1800.0   21.9603    82.4091         Coal         Oil
#
#    commissioning_year                                source  \
# 0              2011.0  National Renewable Energy Laboratory
# 1                 NaN                  Ultratech Cement ltd
# 2                 NaN                                   CDM
# 3              2004.0         Central Electricity Authority
# 4              2015.0         Central Electricity Authority
#
#                      geolocation_source  generation_gwh_2014  \
# 0  National Renewable Energy Laboratory                  NaN
# 1                                   WRI                  NaN
# ...

# %%
df.shape
# Out:
# (907, 13)

# %% [markdown]
# After the dropping of some columns the dataset has 907 rows and 13 columns.

# %%
# Checking again for Null values

df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# source                   0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          907 non-null    float64
#  1   latitude             861 non-null    float64
#  2   longitude            861 non-null    float64
#  3   primary_fuel         907 non-null    object
#  4   other_fuel1          198 non-null    object
#  5   commissioning_year   527 non-null    float64
#  6   source               907 non-null    object
#  7   geolocation_source   888 non-null    object
#  8   generation_gwh_2014  398 non-null    float64
#  9   generation_gwh_2015  422 non-null    float64
#  10  generation_gwh_2016  434 non-null    float64
#  11  generation_gwh_2017  440 non-null    float64
#  12  generation_gwh_2018  448 non-null    float64
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %% [markdown]
# ### Separating categorical and numerical columns.

# %%
cat_columns = []

for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        cat_columns.append(i)
print('Categorical Columns: ', cat_columns)
print('\n')


num_columns = []

for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num_columns.append(i)
print('Numerical Columns: ', num_columns)
# Out:
# Categorical Columns:  ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']
#
#
# Numerical Columns:  ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']

# %%
# For filling in the missing data in the Numerical columns we gonna calculate the mean

df['latitude']=df['latitude'].fillna((df['latitude'].mean()))
df['longitude']=df['longitude'].fillna((df['longitude'].mean()))
df['commissioning_year']=df['commissioning_year'].fillna((df['commissioning_year'].mean()))
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna((df['generation_gwh_2014'].mean()))
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna((df['generation_gwh_2015'].mean()))
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna((df['generation_gwh_2016'].mean()))
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna((df['generation_gwh_2017'].mean()))
df['generation_gwh_2018']=df['generation_gwh_2018'].fillna((df['generation_gwh_2018'].mean()))

# %%
# Using Simle Imputer to fill in the missing data in the categorical columns

from sklearn.impute import SimpleImputer

imp=SimpleImputer(strategy="most_frequent")

df['other_fuel1']=imp.fit_transform(df['other_fuel1'].values.reshape(-1,1))
df['geolocation_source']=imp.fit_transform(df['geolocation_source'].values.reshape(-1,1))

# %%
# Checking again for Null values

df.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# other_fuel1            0
# commissioning_year     0
# source                 0
# geolocation_source     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Now we don't have missing data

# %% [markdown]
# ## Description of the dataset

# %%
# for numerical data

df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  907.000000  907.000000          907.000000
# mean    326.223755   21.197918   77.464907         1997.091082
# std     590.085456    6.079148    4.812291           13.016360
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   17.072000   74.388900         1997.091082
# 50%      59.200000   21.281800   76.979200         1997.091082
# 75%     385.250000   25.176450   79.206100         2003.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           907.000000           907.000000           907.000000
# mean           2431.823590          2428.226946          2467.936859
# std            2665.338608          2859.349132          2877.890004
# min               0.000000             0.000000             0.000000
# ...

# %%
# for object data

df.describe(include="object")
# Out:
#        primary_fuel other_fuel1                         source  \
# count           907         907                            907
# unique            8           3                            191
# top            Coal         Oil  Central Electricity Authority
# freq            258         904                            519
#
#        geolocation_source
# count                 907
# unique                  3
# top                   WRI
# freq                  784

# %% [markdown]
# The 'capacity_mw' column the mean is higher than the median, which means the data is skewed to right.
#
# There is big difference between 75% and max, which indicates the presence of outliers - capacity_mw, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
# Visualization the primary fuel

ax = sns.countplot(x='primary_fuel', data=df)
print(df['primary_fuel'].value_counts())
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# The most common fuels used by the plants are Coal and Hydro, followed by Solar and Wind. Oil and Nuclear are the most unused fuels.

# %%
# Visualization the geolocation_source

ax = sns.countplot(x='geolocation_source', data=df)
print(df['geolocation_source'].value_counts())
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
# Visualization the source

print(df['source'].value_counts())
# Out:
# Central Electricity Authority                                  519
# CDM                                                            124
# Lancosola                                                       10
# National Renewable Energy Laboratory                             8
# National Thermal Power Corporation (NTPC)                        6
#                                                               ...
# Harsha Engineers Limited                                         1
# Godawari Energy ltd                                              1
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Yashwantrao Krishna ssk                                          1
# Name: source, Length: 191, dtype: int64

# %% [markdown]
# The main source reporting the data is Central Electricity Authority.

# %%
# Visualization the other_fuel1

ax = sns.countplot(x='other_fuel1', data=df)
print(df['other_fuel1'].value_counts())
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# The main energy source used in electricity generation (other_fuel1) or export is Oil

# %% [markdown]
# ## Bivariate Analysis

# %%
#Visiualizing the numerical columns vs capacity_mw

plt.figure(figsize=(20,22), facecolor='white')
plotnumber=1
for col in num_columns:
    if plotnumber<=20:
        ax=plt.subplot(10,2,plotnumber) 
        sns.scatterplot(x=df[col],y=df['capacity_mw'], color='m')
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Observation:
#
# 1. 'commissioning_year' : year of plant operation. The newer the year of comission is the higher is the capacity of the plant. Plants comissioned between 2000 and 2020 have higher capacity.
# 2. When we compare the generation in GW/h across teh years between 2014 and 2018 we can see that the generation increases every year.

# %%
# primary_fuel vs capacity_mw 

ax=sns.barplot(x='primary_fuel',y='capacity_mw',data=df)

# %% [markdown]
# From the primary fuel the nuclear fuel is generating more power. After that is Coal and Gas.

# %%
# other_fuel1 vs capacity_mw 

ax=sns.barplot(x='other_fuel1',y='capacity_mw',data=df)

# %% [markdown]
# From other type of fuel most capacity generating is Gas and Oil.

# %%
# source vs capacity_mw 

ax=sns.barplot(x='source',y='capacity_mw',data=df)

# %%
# geolocation_source vs capacity_mw 

ax=sns.barplot(x='geolocation_source',y='capacity_mw',data=df)

# %%
#Visiualizing the numerical columns vs primary_fuel

plt.figure(figsize=(20,22), facecolor='white')
plotnumber=1
for col in num_columns:
    if plotnumber<=20:
        ax=plt.subplot(10,2,plotnumber) 
        sns.scatterplot(x=df[col],y=df['primary_fuel'], color='b')
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# 1. Between years 2000 and 2020 the primary fuel used is Hydro, Gas, Coal.
# 2. The primary fuel used for generating GW/h for the years 2014-2018 was Coal, Hydro and Gas (in that order).

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# As we can see many of the features have linear relationship between one another.

# %% [markdown]
# ## Checking for outliers

# %%
# Checking for outliers only for numerical columns

plt.figure(figsize=(20,35))
pnum=1
for i in num_columns:
    if pnum<=40:
        plt.subplot(10,4,pnum)
        sns.boxplot(df[i],color='b')
        plt.xlabel(i)
    pnum+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# There are outliers presented almost in every feature except 'latitude'.

# %% [markdown]
# ## Removing the outliers

# %%
from scipy.stats import zscore

outliers=df[['capacity_mw', 'longitude', 'commissioning_year', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']]
z=np.abs(zscore(outliers))
z
# Out:
#      capacity_mw  longitude  commissioning_year  generation_gwh_2014  \
# 0       0.548908   0.878280        1.069162e+00         1.707094e-16
# 1       0.386977   0.593788        1.747794e-14         1.707094e-16
# 2       0.486679   1.682394        1.747794e-14         1.707094e-16
# 3       0.324240   2.889052        5.310801e-01         6.809773e-01
# 4       2.498942   1.027976        1.376637e+00         2.266352e-01
# ..           ...        ...                 ...                  ...
# 902     2.159821   0.022477        1.453505e+00         1.707094e-16
# 903     0.548060   0.145644        1.747794e-14         1.707094e-16
# 904     0.509909   0.391673        1.747794e-14         1.707094e-16
# 905     0.417498   0.772866        1.747794e-14         1.707094e-16
# 906     0.525169   0.002473        1.747794e-14         1.707094e-16
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0               0.000000             0.000000         3.114824e-16
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 15,  15,  15,  15,  15, 143, 143, 143, 143, 143, 143, 147, 158,
#        179, 183, 209, 209, 209, 209, 209, 209, 222, 244, 308, 308, 308,
#        308, 308, 308, 323, 333, 340, 342, 360, 363, 364, 364, 364, 364,
#        364, 364, 371, 375, 416, 427, 444, 454, 478, 482, 484, 493, 493,
#        493, 493, 493, 493, 494, 494, 494, 494, 494, 494, 499, 519, 538,
#        541, 546, 573, 577, 583, 592, 601, 621, 638, 648, 648, 648, 648,
#        648, 648, 657, 657, 657, 657, 657, 657, 695, 695, 695, 695, 695,
#        695, 706, 709, 721, 721, 721, 721, 724, 724, 724, 724, 724, 726,
#        726, 726, 726, 726, 726, 728, 767, 786, 786, 786, 786, 786, 786,
#        788, 807, 808, 808, 808, 808, 808, 808, 818, 847, 848, 880, 880,
#        880, 880, 880, 880], dtype=int64), array([0, 4, 5, 6, 7, 0, 3, 4, 5, 6, 7, 0, 3, 1, 1, 0, 3, 4, 5, 6, 7, 2,
#        1, 0, 3, 4, 5, 6, 7, 1, 1, 1, 2, 1, 0, 0, 3, 4, 5, 6, 7, 2, 0, 1,
# ...

# %%
df_new=df[(z<3).all(axis=1)]  
df_new
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         Oil
# 1           98.0   24.7663    74.6090         Coal         Oil
# 2           39.2   21.9038    69.3732         Wind         Oil
# 3          135.0   23.8712    91.3602          Gas         Oil
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         Oil
# 904         25.5   15.2758    75.5811         Wind         Oil
# 905         80.0   24.3500    73.7477         Coal         Oil
# 906         16.5    9.9344    77.4768         Wind         Oil
#
#      commissioning_year                                source  \
# 0           2011.000000  National Renewable Energy Laboratory
# 1           1997.091082                  Ultratech Cement ltd
# ...

# %% [markdown]
# 58 rows have been removed as an outliers.

# %%
# Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df_new.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage: 6.39470782800441

# %%
df=df_new

# %% [markdown]
# ## Checking for skewness

# %%
df.skew()
# Out:
# capacity_mw            1.979914
# latitude              -0.109823
# longitude              0.921980
# commissioning_year    -0.845654
# generation_gwh_2014    1.526648
# generation_gwh_2015    1.389889
# generation_gwh_2016    1.413144
# generation_gwh_2017    1.278735
# generation_gwh_2018    1.315481
# dtype: float64

# %% [markdown]
# There is skewness in capacity_mw, longitude, commission_year, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018.

# %%
plt.figure(figsize=(20,25), facecolor='white')

plotnumber=1

for i in num_columns:   
    if plotnumber<=40:
        plt.subplot(10,4,plotnumber)
        sns.distplot(df[i],color='b')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see in commissioning_year the data is skewed to the left. In capacity_mw, longitude, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018 the data is skewed to the right.

# %% [markdown]
# ## Removing of skewness

# %%
df['commissioning_year'] = df['commissioning_year'].apply(lambda x: np.cbrt(x))
df['capacity_mw'] = df['capacity_mw'].apply(lambda x: np.cbrt(x))
df['longitude'] = df['longitude'].apply(lambda x: np.cbrt(x))
df['generation_gwh_2014'] = df['generation_gwh_2014'].apply(lambda x: np.cbrt(x))
df['generation_gwh_2015'] = df['generation_gwh_2015'].apply(lambda x: np.cbrt(x))
df['generation_gwh_2016'] = df['generation_gwh_2016'].apply(lambda x: np.cbrt(x))
df['generation_gwh_2017'] = df['generation_gwh_2017'].apply(lambda x: np.cbrt(x))
df['generation_gwh_2018'] = df['generation_gwh_2018'].apply(lambda x: np.cbrt(x))

# %%
df.skew()
# Out:
# capacity_mw            0.838288
# latitude              -0.109823
# longitude              0.798807
# commissioning_year    -0.862408
# generation_gwh_2014   -1.219283
# generation_gwh_2015   -1.091320
# generation_gwh_2016   -1.046414
# generation_gwh_2017   -1.064569
# generation_gwh_2018   -1.058711
# dtype: float64

# %% [markdown]
# ## Encoding categorical data

# %%
# Encoding the categorical data into numerical using Label Encoder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['primary_fuel']=le.fit_transform(df['primary_fuel'])
df['other_fuel1']=le.fit_transform(df['other_fuel1'])
df['source']=le.fit_transform(df['source'])
df['geolocation_source']=le.fit_transform(df['geolocation_source'])

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0     1.357209   28.1839   4.183928             6            2
# 1     4.610436   24.7663   4.209822             1            2
# 2     3.396999   21.9038   4.108947             7            2
# 3     5.129928   23.8712   4.503868             2            2
# 4    12.164404   21.9603   4.351694             1            2
#
#    commissioning_year  source  geolocation_source  generation_gwh_2014  \
# 0           12.622267     109                   1            13.447576
# 1           12.593099     174                   2            13.447576
# 2           12.593099      21                   2            13.447576
# 3           12.607604      22                   2             8.516872
# 4           12.630630      22                   2            14.479241
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0            13.440944            13.513816            13.657969
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 849 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          849 non-null    float64
#  1   latitude             849 non-null    float64
#  2   longitude            849 non-null    float64
#  3   primary_fuel         849 non-null    int32
#  4   other_fuel1          849 non-null    int32
#  5   commissioning_year   849 non-null    float64
#  6   source               849 non-null    int32
#  7   geolocation_source   849 non-null    int32
#  8   generation_gwh_2014  849 non-null    float64
#  9   generation_gwh_2015  849 non-null    float64
#  10  generation_gwh_2016  849 non-null    float64
#  11  generation_gwh_2017  849 non-null    float64
#  12  generation_gwh_2018  849 non-null    float64
# dtypes: float64(9), int32(4)
# memory usage: 79.6 KB

# %% [markdown]
# Now we have only numerical data.

# %% [markdown]
# ## Statistical summary

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  primary_fuel  other_fuel1  \
# count   849.000000  849.000000  849.000000    849.000000   849.000000
# mean      4.853649   21.104419    4.253802      3.275618     1.995289
# std       3.008089    6.110636    0.078053      2.324375     0.083984
# min       0.000000    8.168900    4.094514      0.000000     0.000000
# 25%       2.545822   16.924800    4.203176      1.000000     2.000000
# 50%       3.693830   21.197918    4.249398      3.000000     2.000000
# 75%       6.910423   25.129600    4.289455      6.000000     2.000000
# max      12.599210   34.649000    4.511475      7.000000     2.000000
#
#        commissioning_year      source  geolocation_source  \
# count          849.000000  849.000000          849.000000
# mean            12.594734   45.236749            1.717314
# std              0.023452   45.717800            0.693769
# min             12.512521    0.000000            0.000000
# ...

# %% [markdown]
# ## Checking the correlation between the target variable and the independent variables.

# %%
cor=df.corr()
cor
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.060657   0.329848     -0.492607
# latitude                0.060657  1.000000  -0.024176      0.000041
# longitude               0.329848 -0.024176   1.000000     -0.382687
# primary_fuel           -0.492607  0.000041  -0.382687      1.000000
# other_fuel1            -0.030811  0.036878   0.029544      0.006660
# commissioning_year      0.282714  0.102617   0.151588     -0.146092
# source                 -0.368665  0.069393  -0.239559      0.036949
# geolocation_source      0.376189 -0.202748   0.272081     -0.478148
# generation_gwh_2014     0.051496  0.060168  -0.132318      0.080380
# generation_gwh_2015     0.045119  0.047402  -0.155357      0.085791
# generation_gwh_2016     0.088519  0.062277  -0.107202      0.070155
# generation_gwh_2017     0.082096  0.035502  -0.126070      0.086590
# generation_gwh_2018     0.071156  0.047126  -0.114980      0.084539
#
# ...

# %%
# Vusualizing the correlation

plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), linewidths=0.1,fmt='.1g',linecolor='black', annot = True, cmap = 'Blues')
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# ## Correlation with primary_fuel as a target variable

# %%
#Correlation when we have primary_fuel as a target

cor_primary_fuel=cor['primary_fuel'].sort_values(ascending=False)
cor_primary_fuel
# Out:
# primary_fuel           1.000000
# generation_gwh_2017    0.086590
# generation_gwh_2015    0.085791
# generation_gwh_2018    0.084539
# generation_gwh_2014    0.080380
# generation_gwh_2016    0.070155
# source                 0.036949
# other_fuel1            0.006660
# latitude               0.000041
# commissioning_year    -0.146092
# longitude             -0.382687
# geolocation_source    -0.478148
# capacity_mw           -0.492607
# Name: primary_fuel, dtype: float64

# %%
plt.figure(figsize=(25,10))

df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='b')
plt.xlabel('Feature', fontsize=12)
plt.ylabel('Target', fontsize=12)
plt.show()

# %% [markdown]
# 1. There is strong negative correlation between geolocation_source, capacity_mw and the target primary_fuel.
# 2. There is moderate negative correlation between longitude and the target.
# 3. There is mild negative correlation between commissioning_year and the target primary_fuel.
# 4. There is mild possitive correlation between generation_gwh_2017, generation_gwh_2015, generation_gwh_2018, generation_gwh_2014, generation_gwh_2016 and the target primary_fuel.

# %% [markdown]
# ## Correlation with capacity_mw  as a target variable

# %%
## Correlation when capacity_mw as a target

cor_capacity_mw=cor['capacity_mw'].sort_values(ascending=False)
cor_capacity_mw
# Out:
# capacity_mw            1.000000
# geolocation_source     0.376189
# longitude              0.329848
# commissioning_year     0.282714
# generation_gwh_2016    0.088519
# generation_gwh_2017    0.082096
# generation_gwh_2018    0.071156
# latitude               0.060657
# generation_gwh_2014    0.051496
# generation_gwh_2015    0.045119
# other_fuel1           -0.030811
# source                -0.368665
# primary_fuel          -0.492607
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(25,10))

df.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='b')
plt.xlabel('Feature', fontsize=12)
plt.ylabel('Target', fontsize=12)
plt.show()

# %% [markdown]
# 1. There is moderate positive correlation between geological_source, longitude, commissioning_year and the target capacity_mw.
# 2. There is moderate negative correlation between primary_fuel, source and the target capacity_mw.

# %% [markdown]
# # Classification Task ('primary_fuel' as target)

# %% [markdown]
# ## Separating features and label

# %%
x=df.drop(['primary_fuel'],axis=1)
y=df['primary_fuel']

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      capacity_mw  latitude  longitude  other_fuel1  commissioning_year  \
# 0      -1.163031  1.159233  -0.895735     0.056132            1.174673
# 1      -0.080901  0.599617  -0.563787     0.056132           -0.069766
# 2      -0.484530  0.130895  -1.856928     0.056132           -0.069766
# 3       0.091899  0.453048   3.205675     0.056132            0.549098
# 4       2.431798  0.140147   1.254915     0.056132            1.531493
# ..           ...       ...        ...          ...                 ...
# 844     2.276015 -0.787537   0.090764     0.056132            1.620624
# 845    -1.134744 -1.344551   0.280422     0.056132           -0.069766
# 846    -0.635418 -0.954410  -0.330414     0.056132           -0.069766
# 847    -0.181212  0.531449  -0.772259     0.056132           -0.069766
# 848    -0.767659 -1.829041   0.118993     0.056132           -0.069766
#
#        source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values             Features
# 0     1.497090          capacity_mw
# 1     1.077543             latitude
# 2     1.208057            longitude
# 3     1.030044          other_fuel1
# 4     1.144217   commissioning_year
# 5     1.468360               source
# 6     1.529084   geolocation_source
# 7     3.580736  generation_gwh_2014
# 8     6.677897  generation_gwh_2015
# 9    10.809605  generation_gwh_2016
# 10    8.307350  generation_gwh_2017
# 11    9.634186  generation_gwh_2018

# %% [markdown]
# By checking the VIF values we can find the features causing multicollineraty problem.
#
# The VIF in generation_gwh_2018, generation_gwh_2017 and generation_gwh_2016 is slightly high. That means that there is multicollineraty between these features and the other features.
#
# We will drop one of the columns to see if the same issue still exist.

# %%
# Dropping the generation_gwh_2016 column as it has highest VIF

x = x.drop('generation_gwh_2016', axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values             Features
# 0     1.495896          capacity_mw
# 1     1.076288             latitude
# 2     1.202451            longitude
# 3     1.028510          other_fuel1
# 4     1.126441   commissioning_year
# 5     1.468236               source
# 6     1.528885   geolocation_source
# 7     3.567376  generation_gwh_2014
# 8     4.402061  generation_gwh_2015
# 9     7.808976  generation_gwh_2017
# 10    8.649939  generation_gwh_2018

# %% [markdown]
# We gonna drop one more column.

# %%
# Dropping generation_gwh_2018

x.drop('generation_gwh_2018',axis=1,inplace=True)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#    VIF values             Features
# 0    1.495896          capacity_mw
# 1    1.075970             latitude
# 2    1.200259            longitude
# 3    1.012545          other_fuel1
# 4    1.126398   commissioning_year
# 5    1.467355               source
# 6    1.528602   geolocation_source
# 7    3.514762  generation_gwh_2014
# 8    4.257607  generation_gwh_2015
# 9    2.651002  generation_gwh_2017

# %% [markdown]
# Now we have solved multicolinearity issue.

# %% [markdown]
# ## Oversampling

# %%
y.value_counts()
# Out:
# 1    235
# 3    221
# 6    126
# 7    123
# 2     65
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# The target variable (primary_fuel) has imbalanced data.

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 6    235
# 1    235
# 7    235
# 2    235
# 3    235
# 0    235
# 5    235
# 4    235
# Name: primary_fuel, dtype: int64

# %% [markdown]
# # Machine Learning for Classification Task

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.9468085106382979 at random_state 43

# %%
x.head()
# Out:
#    capacity_mw  latitude  longitude  other_fuel1  commissioning_year  \
# 0    -1.163031  1.159233  -0.895735     0.056132            1.174673
# 1    -0.080901  0.599617  -0.563787     0.056132           -0.069766
# 2    -0.484530  0.130895  -1.856928     0.056132           -0.069766
# 3     0.091899  0.453048   3.205675     0.056132            0.549098
# 4     2.431798  0.140147   1.254915     0.056132            1.531493
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0  1.395536           -1.034548             0.385201             0.410442
# 1  2.818140            0.407704             0.385201             0.410442
# 2 -0.530451            0.407704             0.385201             0.410442
# 3 -0.508564            0.407704            -0.851549            -0.542899
# 4 -0.508564            0.407704             0.643969             1.519959
#
#    generation_gwh_2017
# 0             0.412875
# 1             0.412875
# 2             0.412875
# ...

# %%
y.head()
# Out:
# 0    6
# 1    1
# 2    7
# 3    2
# 4    1
# Name: primary_fuel, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=maxRS)

# %%
x_train.shape
# Out:
# (1316, 10)

# %%
y_train.shape
# Out:
# (1316,)

# %%
x_test.shape
# Out:
# (564, 10)

# %%
y_test.shape
# Out:
# (564,)

# %% [markdown]
# ## Random Forest Classifier

# %%
rfc=RandomForestClassifier(n_estimators=200, random_state=42)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
rfcpred= rfc.predict(x_test)
rfcpred
# Out:
# array([3, 2, 1, 0, 2, 4, 6, 2, 0, 6, 2, 0, 7, 6, 5, 4, 2, 3, 4, 6, 0, 2,
#        2, 7, 7, 7, 6, 2, 5, 2, 7, 5, 0, 5, 4, 7, 7, 5, 7, 6, 6, 4, 1, 2,
#        4, 7, 6, 0, 0, 6, 5, 5, 7, 3, 3, 0, 5, 5, 7, 0, 1, 0, 1, 7, 3, 5,
#        7, 4, 5, 3, 2, 4, 5, 3, 3, 6, 1, 1, 6, 4, 4, 3, 5, 5, 7, 5, 7, 6,
#        2, 3, 2, 4, 6, 3, 4, 2, 7, 4, 2, 2, 5, 3, 7, 2, 4, 0, 2, 2, 7, 7,
#        7, 5, 2, 6, 1, 5, 2, 1, 6, 5, 0, 3, 4, 2, 1, 5, 6, 7, 0, 3, 4, 4,
#        7, 0, 7, 1, 3, 7, 2, 3, 0, 6, 5, 5, 6, 6, 4, 4, 4, 4, 0, 2, 6, 7,
#        5, 7, 1, 3, 5, 3, 4, 3, 2, 7, 4, 0, 5, 1, 1, 2, 3, 4, 4, 6, 3, 1,
#        6, 4, 0, 6, 6, 2, 7, 4, 4, 6, 6, 0, 7, 7, 2, 0, 4, 5, 4, 7, 3, 1,
#        0, 6, 6, 4, 0, 0, 7, 4, 6, 6, 6, 5, 2, 4, 0, 7, 4, 4, 4, 5, 7, 3,
#        7, 1, 3, 3, 5, 3, 0, 2, 6, 2, 5, 2, 3, 2, 0, 5, 4, 2, 1, 5, 2, 4,
#        5, 5, 6, 7, 6, 6, 2, 5, 4, 0, 5, 6, 5, 6, 6, 0, 0, 0, 7, 1, 2, 1,
#        2, 2, 4, 1, 1, 4, 0, 4, 2, 5, 5, 0, 3, 0, 2, 3, 3, 4, 7, 4, 2, 6,
# ...

# %%
print(classification_report(y_test,rfcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        72
#            1       0.86      0.75      0.80        57
#            2       0.92      0.94      0.93        70
#            3       0.94      0.87      0.90        68
#            4       0.90      1.00      0.95        81
#            5       0.97      0.97      0.97        71
#            6       1.00      1.00      1.00        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.95       564
#    macro avg       0.94      0.94      0.94       564
# weighted avg       0.95      0.95      0.95       564

# %%
print('Accuracy Score of RFC: ', accuracy_score(y_test, rfcpred))
# Out:
# Accuracy Score of RFC:  0.9468085106382979

# %% [markdown]
# The accuracy for Random Forest Classifier is 95%.

# %% [markdown]
# ## GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print(classification_report(y_test,gnbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74        72
#            1       0.00      0.00      0.00        57
#            2       0.25      0.01      0.03        70
#            3       0.30      1.00      0.46        68
#            4       0.89      0.62      0.73        81
#            5       1.00      0.10      0.18        71
#            6       0.96      0.99      0.97        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.61       564
#    macro avg       0.62      0.59      0.51       564
# weighted avg       0.65      0.61      0.53       564

# %%
print('Accuracy Score of GaussianNB: ', accuracy_score(y_test, gnbpred))
# Out:
# Accuracy Score of GaussianNB:  0.6063829787234043

# %% [markdown]
# ## KNN

# %%
knn=KNeighborsClassifier(n_neighbors=13)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
knnpred=knn.predict(x_test)

# %%
print(classification_report(y_test,knnpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87        72
#            1       0.74      0.51      0.60        57
#            2       0.79      0.77      0.78        70
#            3       0.97      0.49      0.65        68
#            4       0.85      0.99      0.91        81
#            5       0.85      0.90      0.88        71
#            6       1.00      0.97      0.99        78
#            7       0.70      0.96      0.81        67
#
#     accuracy                           0.83       564
#    macro avg       0.84      0.82      0.81       564
# weighted avg       0.84      0.83      0.82       564

# %%
print('Accuracy Score of KNN: ', accuracy_score(y_test, knnpred))
# Out:
# Accuracy Score of KNN:  0.8315602836879432

# %% [markdown]
# ## Logistic regression

# %%
LR=LogisticRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
LRpred=LR.predict(x_test)

# %%
print(classification_report(y_test,LRpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84        72
#            1       0.42      0.44      0.43        57
#            2       0.70      0.47      0.56        70
#            3       0.48      0.43      0.45        68
#            4       0.76      0.75      0.76        81
#            5       0.81      0.72      0.76        71
#            6       1.00      0.97      0.99        78
#            7       0.64      0.91      0.75        67
#
#     accuracy                           0.71       564
#    macro avg       0.70      0.70      0.69       564
# weighted avg       0.71      0.71      0.70       564

# %%
print('Accuracy Score of Logistic Regression: ', accuracy_score(y_test, LRpred))
# Out:
# Accuracy Score of Logistic Regression:  0.7092198581560284

# %% [markdown]
# ## Decision Tree

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtcpred=dtc.predict(x_test)

# %%
print(classification_report(y_test,dtcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        72
#            1       0.71      0.65      0.68        57
#            2       0.80      0.90      0.85        70
#            3       0.80      0.84      0.82        68
#            4       0.92      0.90      0.91        81
#            5       0.93      0.87      0.90        71
#            6       1.00      1.00      1.00        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.90       564
#    macro avg       0.89      0.89      0.89       564
# weighted avg       0.90      0.90      0.90       564

# %%
print('Accuracy Score of Decision Tree Classifier: ', accuracy_score(y_test, dtcpred))
# Out:
# Accuracy Score of Decision Tree Classifier:  0.8971631205673759

# %% [markdown]
# ## Support Vector Classifier

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svcpred=svc.predict(x_test)

# %%
print(classification_report(y_test,svcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88        72
#            1       0.65      0.53      0.58        57
#            2       0.76      0.71      0.74        70
#            3       0.90      0.41      0.57        68
#            4       0.88      1.00      0.94        81
#            5       0.88      0.89      0.88        71
#            6       1.00      1.00      1.00        78
#            7       0.63      1.00      0.77        67
#
#     accuracy                           0.82       564
#    macro avg       0.82      0.80      0.79       564
# weighted avg       0.83      0.82      0.81       564

# %%
print('Accuracy Score of SVC: ', accuracy_score(y_test, svcpred))
# Out:
# Accuracy Score of SVC:  0.8173758865248227

# %% [markdown]
# ## AdaBoostClassifier

# %%
abc=AdaBoostClassifier()

# %%
abc.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
abcpred=abc.predict(x_test)

# %%
print(classification_report(y_test,abcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        72
#            1       0.22      0.40      0.28        57
#            2       0.00      0.00      0.00        70
#            3       0.00      0.00      0.00        68
#            4       0.00      0.00      0.00        81
#            5       0.19      1.00      0.31        71
#            6       1.00      0.97      0.99        78
#            7       0.00      0.00      0.00        67
#
#     accuracy                           0.30       564
#    macro avg       0.18      0.30      0.20       564
# weighted avg       0.18      0.30      0.20       564

# %%
print('Accuracy Score of ABC: ', accuracy_score(y_test, abcpred))
# Out:
# Accuracy Score of ABC:  0.30141843971631205

# %% [markdown]
# ## GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()

# %%
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbpred=gb.predict(x_test)

# %%
print(classification_report(y_test,gbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        72
#            1       0.84      0.74      0.79        57
#            2       0.88      0.90      0.89        70
#            3       0.92      0.85      0.89        68
#            4       0.93      1.00      0.96        81
#            5       0.97      0.96      0.96        71
#            6       1.00      1.00      1.00        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.94       564
#    macro avg       0.93      0.93      0.93       564
# weighted avg       0.94      0.94      0.94       564

# %%
print('Accuracy Score of GBC: ', accuracy_score(y_test, gbpred))
# Out:
# Accuracy Score of GBC:  0.9379432624113475

# %% [markdown]
# ## BaggingClassifier

# %%
bc=BaggingClassifier()

# %%
bc.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
bcpred=bc.predict(x_test)

# %%
print(classification_report(y_test,bcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        72
#            1       0.85      0.70      0.77        57
#            2       0.86      0.91      0.89        70
#            3       0.94      0.87      0.90        68
#            4       0.92      1.00      0.96        81
#            5       0.97      0.94      0.96        71
#            6       1.00      1.00      1.00        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.93       564
#    macro avg       0.93      0.93      0.93       564
# weighted avg       0.93      0.93      0.93       564

# %%
print('Accuracy Score of BC: ', accuracy_score(y_test, bcpred))
# Out:
# Accuracy Score of BC:  0.9343971631205674

# %% [markdown]
# ## Extra Trees Classifier

# %%
et=ExtraTreesClassifier()

# %%
et.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
etpred=et.predict(x_test)

# %%
print(classification_report(y_test,etpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        72
#            1       0.86      0.77      0.81        57
#            2       0.94      0.97      0.96        70
#            3       0.95      0.91      0.93        68
#            4       0.94      1.00      0.97        81
#            5       1.00      0.97      0.99        71
#            6       1.00      1.00      1.00        78
#            7       1.00      1.00      1.00        67
#
#     accuracy                           0.96       564
#    macro avg       0.96      0.95      0.95       564
# weighted avg       0.96      0.96      0.96       564

# %%
print('Accuracy Score of ETC: ', accuracy_score(y_test, etpred))
# Out:
# Accuracy Score of ETC:  0.9592198581560284

# %% [markdown]
# The best accuracy score gives us ExtraTree Classifier (96%), RandomForest accuracy score is 95%, GradientBoosting gives us 94%.

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# CV score for RandomForest Classifier

score=cross_val_score(rfc,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and Random Forest Score is  ', accuracy_score(y_test, rfcpred) - score.mean())
# Out:
# Score:  [0.89095745 0.91489362 0.94414894 0.92553191 0.91755319]
# Mean Score:  0.9186170212765958
# Std deviation:  0.017203150668932164
# Difference between Accuracy score and Random Forest Score is   0.028191489361702016

# %%
# CV score for Support Vector Classifier

score=cross_val_score(svc,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and Support Vector Score is  ', accuracy_score(y_test, svcpred) - score.mean())
# Out:
# Score:  [0.82446809 0.81648936 0.80851064 0.81382979 0.81648936]
# Mean Score:  0.8159574468085108
# Std deviation:  0.005157106231294005
# Difference between Accuracy score and Support Vector Score is   0.0014184397163119478

# %%
# CV score for DecisionTree Classifier

score=cross_val_score(dtc,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and Decision Tree Score is  ', accuracy_score(y_test, dtcpred) - score.mean())
# Out:
# Score:  [0.8643617  0.87234043 0.90957447 0.8643617  0.88829787]
# Mean Score:  0.8797872340425533
# Std deviation:  0.017268811788029678
# Difference between Accuracy score and Decision Tree Score is   0.01737588652482258

# %%
# CV score for KNN Classifier

score=cross_val_score(knn,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and KNN Score is  ', accuracy_score(y_test, knnpred) - score.mean())
# Out:
# Score:  [0.81117021 0.79521277 0.80053191 0.82712766 0.82446809]
# Mean Score:  0.8117021276595745
# Std deviation:  0.0126322788159978
# Difference between Accuracy score and KNN Score is   0.019858156028368712

# %%
# CV score for GNB Classifier

score=cross_val_score(gnb,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and GNB Score is  ', accuracy_score(y_test, gnbpred) - score.mean())
# Out:
# Score:  [0.58776596 0.58244681 0.59574468 0.57712766 0.59574468]
# Mean Score:  0.5877659574468085
# Std deviation:  0.007331940825579882
# Difference between Accuracy score and GNB Score is   0.018617021276595813

# %%
# CV score for AB Classifier

score=cross_val_score(abc,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and ABC Score is  ', accuracy_score(y_test, abcpred) - score.mean())
# Out:
# Score:  [0.28989362 0.2712766  0.27659574 0.28989362 0.28191489]
# Mean Score:  0.28191489361702127
# Std deviation:  0.007331940825579905
# Difference between Accuracy score and ABC Score is   0.01950354609929078

# %%
# CV score for GB Classifier

score=cross_val_score(gb,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and GB Score is  ', accuracy_score(y_test, gbpred) - score.mean())
# Out:
# Score:  [0.90957447 0.8962766  0.92021277 0.90957447 0.91755319]
# Mean Score:  0.9106382978723404
# Std deviation:  0.00834275911774367
# Difference between Accuracy score and GB Score is   0.027304964539007104

# %%
# CV score for Bagging Classifier

score=cross_val_score(bc,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and Bagging Classifier Score is  ', accuracy_score(y_test, bcpred) - score.mean())
# Out:
# Score:  [0.8962766  0.8962766  0.93351064 0.90691489 0.91489362]
# Mean Score:  0.9095744680851064
# Std deviation:  0.013870643415324752
# Difference between Accuracy score and Bagging Classifier Score is   0.024822695035460973

# %%
# CV score for Extra Tree Classifier

score=cross_val_score(et,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print('Difference between Accuracy score and Extra Tree Score is  ', accuracy_score(y_test, etpred) - score.mean())
# Out:
# Score:  [0.93085106 0.94148936 0.94680851 0.94148936 0.94680851]
# Mean Score:  0.9414893617021276
# Std deviation:  0.005826835718140063
# Difference between Accuracy score and Extra Tree Score is   0.01773049645390079

# %% [markdown]
# Both classifiers Extra Tree and Randon Forest have hight accuracy - 96% and 95%. Both of them have very low difference between the accuracy score and the mean score - 0.02 and 0.03.

# %% [markdown]
# ## Hyper Rarameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'n_estimators':[10, 20, 30, 40],
             'criterion':['gini', 'entropy', 'log_loss'],
             'max_depth':[10, 30, 50],
             'max_features':['sqrt', 'log2', None],
             'max_leaf_nodes':[10,50,100]}

# %%
GSCV=GridSearchCV(ExtraTreesClassifier(),param,cv=5)

# %%
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [10, 30, 50],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [10, 50, 100],
#                          'n_estimators': [10, 20, 30, 40]})

# %%
GSCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 50,
#  'max_features': None,
#  'max_leaf_nodes': 100,
#  'n_estimators': 20}

# %%
Final_model_classification=ExtraTreesClassifier(criterion= 'gini', max_depth= 50, max_features= None, max_leaf_nodes= 100, n_estimators= 20)
Final_model_classification.fit(x_train, y_train)
prediction=Final_model_classification.predict(x_test)

print("R2 score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediction)))
print("Accuracy score", accuracy_score(y_test, prediction) *100)
# Out:
# R2 score: 0.9347763436057308
# Mean Absolute Error: 0.13652482269503546
# Mean Squared Error: 0.3351063829787234
# Root Mean Squared Error: 0.5788837387409699
# Accuracy score 92.90780141843972

# %%
etpred
# Out:
# array([3, 2, 1, 0, 2, 4, 6, 2, 0, 6, 2, 0, 7, 6, 5, 4, 3, 3, 4, 6, 0, 2,
#        2, 7, 7, 7, 6, 2, 5, 2, 7, 5, 0, 5, 4, 7, 7, 5, 7, 6, 6, 4, 1, 2,
#        4, 7, 6, 0, 0, 6, 5, 5, 7, 3, 3, 0, 5, 5, 7, 0, 1, 0, 1, 7, 3, 5,
#        7, 4, 5, 3, 2, 4, 5, 3, 5, 6, 1, 1, 6, 4, 4, 3, 5, 5, 7, 5, 7, 6,
#        2, 3, 2, 4, 6, 3, 4, 2, 7, 4, 2, 2, 5, 3, 7, 2, 4, 0, 2, 2, 7, 7,
#        7, 5, 2, 6, 1, 5, 2, 1, 6, 5, 0, 3, 1, 3, 1, 5, 6, 7, 0, 3, 4, 4,
#        7, 0, 7, 1, 3, 7, 2, 3, 0, 6, 5, 5, 6, 6, 4, 4, 4, 4, 0, 2, 6, 7,
#        5, 7, 1, 3, 5, 3, 4, 3, 2, 7, 4, 0, 5, 1, 1, 2, 3, 4, 4, 6, 3, 1,
#        6, 4, 0, 6, 6, 2, 7, 4, 4, 6, 6, 0, 7, 7, 2, 0, 4, 5, 4, 7, 3, 1,
#        0, 6, 6, 4, 0, 0, 7, 4, 6, 6, 6, 5, 2, 4, 0, 7, 4, 4, 4, 5, 7, 3,
#        7, 1, 3, 3, 1, 3, 0, 2, 6, 2, 5, 2, 3, 2, 0, 2, 1, 2, 1, 5, 2, 4,
#        5, 5, 6, 7, 6, 6, 2, 5, 4, 0, 5, 6, 5, 6, 6, 0, 0, 0, 7, 1, 2, 1,
#        2, 2, 4, 3, 1, 4, 0, 4, 2, 5, 5, 0, 3, 0, 2, 3, 3, 4, 7, 4, 2, 6,
# ...

# %%
print(confusion_matrix(y_test, etpred))
# Out:
# [[72  0  0  0  0  0  0  0]
#  [ 3 44  3  3  4  0  0  0]
#  [ 0  2 68  0  0  0  0  0]
#  [ 0  4  1 62  1  0  0  0]
#  [ 0  0  0  0 81  0  0  0]
#  [ 1  1  0  0  0 69  0  0]
#  [ 0  0  0  0  0  0 78  0]
#  [ 0  0  0  0  0  0  0 67]]

# %% [markdown]
# # Saving the classification model

# %%
import joblib

import joblib

joblib.dump(et, 'Global-Power-Plant-Classification.pkl.obj')
# Out:
# ['Global-Power-Plant-Classification.pkl.obj']

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
fpr, tpr, thresholds =roc_curve(y_test, prediction, pos_label=1)

# %%
fpr
# Out:
# array([0.        , 0.1321499 , 0.28599606, 0.4260355 , 0.59368836,
#        0.70808679, 0.83629191, 0.85404339, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.12280702,
#        0.15789474, 0.24561404, 0.92982456, 1.        ])

# %%
roc_auc=metrics.auc(fpr,tpr)

# %%
display=metrics.RocCurveDisplay(fpr = fpr, tpr=tpr, roc_auc=roc_auc,estimator_name=Final_model_classification)

# %%
display.plot()

# %% [markdown]
# # Regression Task ('capacity_mw ' as target)

# %% [markdown]
# ## Separating features and label

# %%
x1=df.drop(['capacity_mw'],axis=1)
y1=df['capacity_mw']

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x1=pd.DataFrame(scaler.fit_transform(x1), columns=x1.columns)
x1
# Out:
#      latitude  longitude  primary_fuel  other_fuel1  commissioning_year  \
# 0    1.159233  -0.895735      1.172783     0.056132            1.174673
# 1    0.599617  -0.563787     -0.979601     0.056132           -0.069766
# 2    0.130895  -1.856928      1.603260     0.056132           -0.069766
# 3    0.453048   3.205675     -0.549124     0.056132            0.549098
# 4    0.140147   1.254915     -0.979601     0.056132            1.531493
# ..        ...        ...           ...          ...                 ...
# 844 -0.787537   0.090764     -0.979601     0.056132            1.620624
# 845 -1.344551   0.280422      1.172783     0.056132           -0.069766
# 846 -0.954410  -0.330414      1.603260     0.056132           -0.069766
# 847  0.531449  -0.772259     -0.979601     0.056132           -0.069766
# 848 -1.829041   0.118993      1.603260     0.056132           -0.069766
#
#        source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features']=x1.columns

vif
# Out:
#     VIF values             Features
# 0     1.075607             latitude
# 1     1.286667            longitude
# 2     1.630924         primary_fuel
# 3     1.027339          other_fuel1
# 4     1.086991   commissioning_year
# 5     1.547117               source
# 6     1.962319   geolocation_source
# 7     3.579773  generation_gwh_2014
# 8     6.675907  generation_gwh_2015
# 9    10.801378  generation_gwh_2016
# 10    8.279566  generation_gwh_2017
# 11    9.634744  generation_gwh_2018

# %% [markdown]
# The feautures generation_gwh_2016, generation_gwh_2018,generation_gwh_2017 have slightly high VIF. We gonna try to reduce it by dropping one of the columns.

# %%
x1 = x1.drop('generation_gwh_2016', axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features']=x1.columns

vif
# Out:
#     VIF values             Features
# 0     1.074140             latitude
# 1     1.280350            longitude
# 2     1.630865         primary_fuel
# 3     1.025916          other_fuel1
# 4     1.067344   commissioning_year
# 5     1.547117               source
# 6     1.962222   geolocation_source
# 7     3.566136  generation_gwh_2014
# 8     4.402525  generation_gwh_2015
# 9     7.773900  generation_gwh_2017
# 10    8.650839  generation_gwh_2018

# %% [markdown]
# We gonna drop generation_gwh_2018 as we still have high VIF.

# %%
x1 = x1.drop('generation_gwh_2018', axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features']=x1.columns

vif
# Out:
#    VIF values             Features
# 0    1.073777             latitude
# 1    1.277784            longitude
# 2    1.630695         primary_fuel
# 3    1.010012          other_fuel1
# 4    1.067316   commissioning_year
# 5    1.545979               source
# 6    1.962135   geolocation_source
# 7    3.513608  generation_gwh_2014
# 8    4.257917  generation_gwh_2015
# 9    2.617007  generation_gwh_2017

# %% [markdown]
# Now we have solved multicolinearity issue.

# %% [markdown]
# # Machine Learning for Regression Task

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## Finding the best random state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x1_train,y1_train)
    pred=lr.predict(x1_test)
    acc=r2_score(y1_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.5358401853891415 on random state 90

# %%
x1.head()
# Out:
#    latitude  longitude  primary_fuel  other_fuel1  commissioning_year  \
# 0  1.159233  -0.895735      1.172783     0.056132            1.174673
# 1  0.599617  -0.563787     -0.979601     0.056132           -0.069766
# 2  0.130895  -1.856928      1.603260     0.056132           -0.069766
# 3  0.453048   3.205675     -0.549124     0.056132            0.549098
# 4  0.140147   1.254915     -0.979601     0.056132            1.531493
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0  1.395536           -1.034548             0.385201             0.410442
# 1  2.818140            0.407704             0.385201             0.410442
# 2 -0.530451            0.407704             0.385201             0.410442
# 3 -0.508564            0.407704            -0.851549            -0.542899
# 4 -0.508564            0.407704             0.643969             1.519959
#
#    generation_gwh_2017
# 0             0.412875
# 1             0.412875
# 2             0.412875
# ...

# %%
y1.head()
# Out:
# 0     1.357209
# 1     4.610436
# 2     3.396999
# 3     5.129928
# 4    12.164404
# Name: capacity_mw, dtype: float64

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.3, random_state=maxRS)

# %%
x1_train.shape
# Out:
# (594, 10)

# %%
y1_train.shape
# Out:
# (594,)

# %%
x1_test.shape
# Out:
# (255, 10)

# %%
y1_test.shape
# Out:
# (255,)

# %% [markdown]
# ## Linear Regression

# %%
lr=LinearRegression()

# %%
lr.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
lr.score(x1_train, y1_train)
# Out:
# 0.43478370350160644

# %%
lrpred=lr.predict(x1_test)

# %%
print('R2_score: ', r2_score(y1_test,lrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,lrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,lrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,lrpred)))
# Out:
# R2_score:  0.47635554627135457
# Mean Absolute Error:  1.8564740592725233
# Mean Squared Error:  5.173284231322362
# Root Mean Squared Error:  2.2744854871645943

# %% [markdown]
# ## Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x1_train,y1_train)
# Out:
# DecisionTreeRegressor()

# %%
dtrpred=dtr.predict(x1_test)

# %%
dtr.score(x1_train, y1_train)
# Out:
# 0.9974521923810143

# %%
print('R2_score: ', r2_score(y1_test,dtrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,dtrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,dtrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,dtrpred)))
# Out:
# R2_score:  0.7397360341766863
# Mean Absolute Error:  1.0974472354405838
# Mean Squared Error:  2.5712474576745743
# Root Mean Squared Error:  1.60351097834551

# %% [markdown]
# ## Support Vector Regressor

# %%
svr=SVR()
svr.fit(x1_train,y1_train)
svrpred=svr.predict(x1_test)

# %%
svr.score(x1_train, y1_train)
# Out:
# 0.7025741474189675

# %%
print('R2_score: ', r2_score(y1_test,svrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,svrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,svrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,svrpred)))
# Out:
# R2_score:  0.6806696077665029
# Mean Absolute Error:  1.2708275211372564
# Mean Squared Error:  3.154787319832096
# Root Mean Squared Error:  1.7761720974703143

# %% [markdown]
# ## Random Forest Regressor

# %%
rfr=RandomForestRegressor(n_estimators=200, random_state=maxRS)
rfr.fit(x1_train, y1_train)
rfrpred= rfr.predict(x1_test)

# %%
rfr.score(x1_train, y1_train)
# Out:
# 0.9721531679989268

# %%
print('R2_score: ', r2_score(y1_test,rfrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,rfrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,rfrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,rfrpred)))
# Out:
# R2_score:  0.859071741542398
# Mean Absolute Error:  0.8102803396469246
# Mean Squared Error:  1.392284272343764
# Root Mean Squared Error:  1.179950961838569

# %% [markdown]
# ## AdaBoost Regressor

# %%
abr=AdaBoostRegressor()
abr.fit(x1_train,y1_train)
abrpred=abr.predict(x1_test)

# %%
abr.score(x1_train, y1_train)
# Out:
# 0.787447736620754

# %%
print('R2_score: ', r2_score(y1_test,abrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,abrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,abrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,abrpred)))
# Out:
# R2_score:  0.7915315466144848
# Mean Absolute Error:  1.1432084798684525
# Mean Squared Error:  2.0595397410364105
# Root Mean Squared Error:  1.4351096616762116

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge

rr=Ridge()
rr.fit(x1_train,y1_train)
rrpred=rr.predict(x1_test)

# %%
rr.score(x1_train, y1_train)
# Out:
# 0.43478166803024487

# %%
print('R2_score: ', r2_score(y1_test,rrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test,rrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test,rrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test,rrpred)))
# Out:
# R2_score:  0.4761761199324406
# Mean Absolute Error:  1.857236076761308
# Mean Squared Error:  5.175056852884909
# Root Mean Squared Error:  2.2748751290752

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso

lasso=Lasso()
lasso.fit(x1_train,y1_train)
lassopred=lasso.predict(x1_test)

# %%
lasso.score(x1_train, y1_train)
# Out:
# 0.13970407825590625

# %%
print('R2_score: ', r2_score(y1_test, lassopred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test, lassopred))
print('Mean Squared Error: ', mean_squared_error(y1_test, lassopred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test, lassopred)))
# Out:
# R2_score:  0.13049169687596518
# Mean Absolute Error:  2.462928466405971
# Mean Squared Error:  8.590205742705002
# Root Mean Squared Error:  2.9309052769929296

# %% [markdown]
# ## KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor()
knr.fit(x1_train,y1_train)
knrpred=knr.predict(x1_test)

# %%
knr.score(x1_train, y1_train)
# Out:
# 0.7775029684099405

# %%
print('R2_score: ', r2_score(y1_test, knrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test, knrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test, knrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test, knrpred)))
# Out:
# R2_score:  0.71212994401524
# Mean Absolute Error:  1.112560609073242
# Mean Squared Error:  2.843978601686042
# Root Mean Squared Error:  1.686409974379315

# %% [markdown]
# ## GradientBoosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr=GradientBoostingRegressor()
gbr.fit(x1_train,y1_train)
gbrpred=gbr.predict(x1_test)

# %%
gbr.score(x1_train, y1_train)
# Out:
# 0.9187638219275838

# %%
print('R2_score: ', r2_score(y1_test, gbrpred))
print('Mean Absolute Error: ', mean_absolute_error(y1_test, gbrpred))
print('Mean Squared Error: ', mean_squared_error(y1_test, gbrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y1_test, gbrpred)))
# Out:
# R2_score:  0.8684226983188812
# Mean Absolute Error:  0.8109304718974415
# Mean Squared Error:  1.2999025868411318
# Root Mean Squared Error:  1.140132705802764

# %% [markdown]
# GradientBoosting Regressor and RandomForest Regressor have highest r2 score - 0.87 and 0.86. Both regressors have low errors.

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#CV score for Linear Regression

score=cross_val_score(lr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,lrpred)-score.mean())*100)
# Out:
# Score:  [0.38662221 0.45150177 0.36259673 0.46926299 0.475036  ]
# Mean Score:  0.42900394168582945
# Std deviation:  0.04572094287152736
# Difference between R2 score and CVS is:  4.735160458552512

# %%
#CV score for DTR

score=cross_val_score(dtr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,dtrpred)-score.mean())*100)
# Out:
# Score:  [0.73546523 0.69547155 0.66203254 0.75891098 0.73760001]
# Mean Score:  0.7178960623344617
# Std deviation:  0.03464891239444623
# Difference between R2 score and CVS is:  2.1839971842224637

# %%
#CV score for SVR

score=cross_val_score(svr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,svrpred)-score.mean())*100)
# Out:
# Score:  [0.68416069 0.62250835 0.61101366 0.73199233 0.68821502]
# Mean Score:  0.6675780105627356
# Std deviation:  0.04490183845037634
# Difference between R2 score and CVS is:  1.3091597203767291

# %%
#CV score for RFR

score=cross_val_score(rfr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,rfrpred)-score.mean())*100)
# Out:
# Score:  [0.82614699 0.84596814 0.74952073 0.85495802 0.84537328]
# Mean Score:  0.824393433681862
# Std deviation:  0.038597440791739726
# Difference between R2 score and CVS is:  3.467830786053594

# %%
#CV score for ABR

score=cross_val_score(abr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,abrpred)-score.mean())*100)
# Out:
# Score:  [0.73547153 0.79129001 0.71767116 0.77378205 0.75423793]
# Mean Score:  0.7544905379728636
# Std deviation:  0.02624430273763954
# Difference between R2 score and CVS is:  3.7041008641621187

# %%
#CV score for Ridge Regressor

score=cross_val_score(rr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,rrpred)-score.mean())*100)
# Out:
# Score:  [0.38728565 0.45159126 0.3627011  0.46912459 0.47472282]
# Mean Score:  0.4290850817275536
# Std deviation:  0.045489601354009854
# Difference between R2 score and CVS is:  4.709103820488697

# %%
#CV score for Lasso Regressor

score=cross_val_score(lasso,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,lassopred)-score.mean())*100)
# Out:
# Score:  [0.16031268 0.1656673  0.12474897 0.11739234 0.15786298]
# Mean Score:  0.1451968526422328
# Std deviation:  0.019995823373856626
# Difference between R2 score and CVS is:  -1.470515576626763

# %%
#CV score for KNeighbors Regressor

score=cross_val_score(knr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,knrpred)-score.mean())*100)
# Out:
# Score:  [0.67007016 0.66149608 0.61755104 0.72714508 0.71571012]
# Mean Score:  0.678394494233413
# Std deviation:  0.03956223707384072
# Difference between R2 score and CVS is:  3.3735449781826965

# %%
#CV score for GradientBoosting Regressor

score=cross_val_score(gbr,x1,y1, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y1_test,gbrpred)-score.mean())*100)
# Out:
# Score:  [0.81556126 0.87320709 0.7767611  0.83716245 0.85160272]
# Mean Score:  0.8308589228321811
# Std deviation:  0.03293630044771906
# Difference between R2 score and CVS is:  3.756377548670009

# %% [markdown]
# # Hyper Parameter Tuning

# %%
param={'n_estimators':[40, 60, 80, 100],
             'criterion':['squared_error', 'friedman_mse'],
             'max_depth':[2, 3, 10, 20,30],
             'min_samples_leaf':[1, 5, 10, 15, 20],
             'learning_rate':[0.0, 0.1, 0.5,1.0, 2.0]}

# %%
GSCV_1=GridSearchCV(GradientBoostingRegressor(),param,cv=5)

# %%
GSCV_1.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'learning_rate': [0.0, 0.1, 0.5, 1.0, 2.0],
#                          'max_depth': [2, 3, 10, 20, 30],
#                          'min_samples_leaf': [1, 5, 10, 15, 20],
#                          'n_estimators': [40, 60, 80, 100]})

# %%
GSCV_1.best_params_
# Out:
# {'criterion': 'squared_error',
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'min_samples_leaf': 10,
#  'n_estimators': 100}

# %%
Final_model_regression=GradientBoostingRegressor(n_estimators=100, criterion= 'squared_error', max_depth=3, learning_rate=0.1, min_samples_leaf= 10)
Final_model_regression.fit(x1_train, y1_train)
prediction=Final_model_regression.predict(x1_test)

print("R2 score:",r2_score(y1_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y1_test,prediction))
print("Mean Squared Error:",mean_squared_error(y1_test,prediction))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y1_test,prediction)))
# Out:
# R2 score: 0.8663926767673954
# Mean Absolute Error: 0.8245376762623178
# Mean Squared Error: 1.3199579477005206
# Root Mean Squared Error: 1.1488942282475443

# %% [markdown]
# # Saving the model

# %%
joblib.dump(rfr, 'Global-Power-Plant-Regression.pkl.obj')
# Out:
# ['Global-Power-Plant-Regression.pkl.obj']
