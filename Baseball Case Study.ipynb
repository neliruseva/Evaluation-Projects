# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# ## Project Description

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# ### Input features

# %% [markdown]
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# ### Output:
# Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %% [markdown]
# ## Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#Checking the dimentions of the dataset

df.shape
# Out:
# (30, 17)

# %%
#Checking the columns of the dataset

df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
# Checking the types of columns

df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# Checking the null values

df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# As we can see there are no null values presented in this dataset. We can also use heatmap to visualize this.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Checking for unique values of each column.

for i in df.columns:
    print(df[i].unique())
    print("\n")
# Out:
# [ 95  83  81  76  74  93  87  80  78  88  86  85  68 100  98  97  64  90
#   71  67  63  92  84  79]
#
#
# [724 696 669 622 689 891 764 713 644 748 751 729 661 656 694 647 697 655
#  640 683 703 613 573 626 667 720 650 737]
#
#
# [5575 5467 5439 5533 5605 5509 5567 5485 5640 5511 5459 5417 5544 5600
#  5484 5631 5491 5480 5571 5527 5428 5463 5420 5529 5385 5565 5649 5457
#  5572]
#
#
# [1497 1349 1395 1381 1515 1480 1397 1370 1383 1495 1419 1363 1331 1379
#  1405 1386 1462 1341 1378 1382 1351 1420 1361 1374 1346 1486 1494 1324
#  1479]
#
#
# [300 277 303 260 289 308 272 246 278 294 279 243 262 288 292 274 257 295
#  265 236 251 263]
#
#
# [42 44 29 27 49 17 19 20 32 33 26 21 22 46 39 30 34 13 40 18 37 48 36]
#
#
# [139 156 141 136 151 232 212 217 167 161 172 230 176 198 146 137 140 171
#  145 177 120 100 130 187 154 148 186]
#
#
# [383 439 533 404 455 570 554 418 436 478 503 486 435 475 506 461 567 412
#  496 488 539 375 471 387 563 457 490 426 388]
#
#
# [ 973 1264 1157 1231 1259 1151 1227 1331 1310 1148 1233 1392 1150 1336
#  1119 1267 1322 1518 1299 1255 1290 1344 1107 1274 1258 1159 1312 1327
#  1283]
#
#
# [104  70  86  68  83  88  63  44  87  71 101 121  52  69  78  98  95  84
#  134  51  57 112  59  93 132  82  97]
#
#
# [641 700 640 701 803 670 698 693 642 753 733 618 675 726 729 525 596 608
#  737 754 613 635 678 760 809 595 627 713 731 844]
#
#
# [601 653 584 643 746 609 652 646 604 694 680 572 630 677 664 478 532 546
#  682 700 557 577 638 698 749 553 597 659 655 799]
#
#
# [3.73 4.07 3.67 3.98 4.64 3.8  4.03 4.05 3.74 4.31 4.24 3.57 3.94 4.16
#  4.14 2.94 3.21 3.36 4.28 4.33 3.43 3.62 4.02 4.41 4.69 3.44 3.72 4.04
#  4.09 5.04]
#
#
# [ 2 11  7  3  0  1  5  6  4]
#
#
# [ 8 12 10  9  4 13 15 21  7 14 18  6]
#
#
# [56 45 38 37 35 34 48 43 60 40 39 46 28 62 54 50 41 44 47 36]
#
#
# [ 88  86  79 101  93  77  95  97 119  85  94 126  96 122 111 116  90 117
#   75  78  92]

# %%
df.nunique().to_frame("Number of unique values")
# Out:
#      Number of unique values
# W                         24
# R                         28
# AB                        29
# H                         29
# 2B                        22
# 3B                        23
# HR                        27
# BB                        29
# SO                        29
# SB                        27
# RA                        30
# ER                        30
# ERA                       30
# CG                         9
# SHO                       12
# SV                        20
# E                         21

# %%
#Checking the value counts of each column.

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
#
#
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64
#
#
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64
#
#
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64
#
#
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64
#
#
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64
#
#
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64
#
#
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64
#
#
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64
#
#
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64
#
#
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64
#
#
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64
#
#
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64
#
#
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64
#
#
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %%
# Checking the values counts in target column

df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# ## Description of the dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# That gives us statistical information about the columns.
#
# #### Observation:
#
# 1. The counts of all columns are the same which means there are no missing values in the dataset.
# 2. The mean value is greater than the median (50th percentile) in H, HR, SV, E. Which means the data in these columns is skewed to the right.
# 3. The mean value is less than the median (50%) value in  BB, SO, RA, ER, ERA, SHO.Which means the data in these columns is skewed to the left.
# 4. There is huge difference between the 75% and the max which means outliers are presented.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
# Visualizing the number of Wins credited to a pitcher

ax = sns.countplot(x='W', data=df)
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# The highest number of wins has 68, followed by 74, 76, 81 and 83.

# %%
# Visualizing the Runs scored

ax = sns.countplot(x='R', data=df)
print(df['R'].value_counts())
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64

# %% [markdown]
# The highest number of runs scored have 689 and 696.

# %%
# Visualizing the time at bat

ax = sns.countplot(x='AB', data=df)
print(df['AB'].value_counts())
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64

# %% [markdown]
# 5485 has highest time at bat. While the rest are the same.

# %%
# Visualizing the base hit

ax = sns.countplot(x='H', data=df)
print(df['H'].value_counts())
# Out:
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64

# %%
# Visualizing the two base hit

ax = sns.countplot(x='2B', data=df)
print(df['2B'].value_counts())
# Out:
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64

# %%
# Visualizing the three base hit

ax = sns.countplot(x='3B', data=df)
print(df['3B'].value_counts())
# Out:
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64

# %%
# Visualizing the Home runs

ax = sns.countplot(x='HR', data=df)
print(df['HR'].value_counts())
# Out:
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64

# %%
# Visualizing the Base on balls 

ax = sns.countplot(x='BB', data=df)
print(df['BB'].value_counts())
# Out:
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64

# %%
# Visualizing the Strikeout

ax = sns.countplot(x='SO', data=df)
print(df['SO'].value_counts())
# Out:
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64

# %%
# Visualizing the Stolen base

ax = sns.countplot(x='SB', data=df)
print(df['SB'].value_counts())
# Out:
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64

# %%
# Visualizing the Run Average

ax = sns.countplot(x='RA', data=df)
print(df['RA'].value_counts())
# Out:
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64

# %%
# Visualizing the Earned run

ax = sns.countplot(x='ER', data=df)
print(df['ER'].value_counts())
# Out:
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64

# %%
# Visualizing the Earned Run Average

ax = sns.countplot(x='ERA', data=df)
print(df['ERA'].value_counts())
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64

# %%
# Visualizing the Complete Game

ax = sns.countplot(x='CG', data=df)
print(df['CG'].value_counts())
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %%
# Visualizing the Shutout

ax = sns.countplot(x='SHO', data=df)
print(df['SHO'].value_counts())
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64

# %%
# Visualizing the Save

ax = sns.countplot(x='SV', data=df)
print(df['SV'].value_counts())
# Out:
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64

# %%
# Visualizing the Errors

ax = sns.countplot(x='E', data=df)
print(df['E'].value_counts())
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %%
# Checking how the data has been distributed 

plt.figure(figsize=(20,16), facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=18:
        ax=plt.subplot(9,2,plotnumber) 
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The data is distributed normal. In the columns R and CG the data is slightly sckewed to the right.

# %% [markdown]
# ## Bivariate Analysis

# %%
# Comparing all columns with the target column W

plt.figure(figsize=(20,25), facecolor='white')
pnumber=1
for i in df.columns:
    if pnumber<=18:    
        plt.subplot(5,4,pnumber) 
        sns.scatterplot(x=df[i],y='W',data=df,color='b')
        plt.xlabel(i)
        plt.ylabel('W')
    pnumber+=1
plt.show()

# %%
# Visualizing Features with Target

plt.figure(figsize=(20,25), facecolor='white')
p=1
for i in df.columns:
    if p<=18:    
        plt.subplot(5,4,p) 
        sns.regplot(x=df[i],y='W',data=df,color='b')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %% [markdown]
# 1. There is relation between SV and W. As the SV increases, W increases too.
# 2. There is also relation between RA, ER and ERA. As RA, ER and ERA increse, W is decreasing.
# 3. Rest of the columns don`t have good relation with W.

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## Checking for outliers

# %%
plt.figure(figsize=(20,25))
pnum=1
for i in df.columns:
    if pnum<=18:
        plt.subplot(5,4,pnum)
        sns.boxplot(df[i],color='b')
        plt.xlabel(i)
    pnum+=1
plt.show()

# %% [markdown]
# We can see that there are some outliers presented in R,ERA,SHO,SV,E columns.

# %% [markdown]
# ## Removing the outliers

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# RA  -0.641579 -0.642734  0.195846
# ER  -0.637293 -0.621875  0.131556
# ERA -0.637186 -0.637755  0.108191
# CG   0.264346 -0.332806 -0.123447
# SHO  1.000000  0.214175 -0.121484
# SV   0.214175  1.000000 -0.045539
# E   -0.121484 -0.045539  1.000000

# %%
# Vusualizing the correlation

plt.figure(figsize=(15,8))
sns.heatmap(df_new.corr(), annot = True, cmap = 'Blues')
plt.yticks(rotation=0);
plt.show()

# %%
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.749290
# SHO    0.497526
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# CG     0.029594
# H     -0.018360
# E     -0.072858
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %% [markdown]
# #### Observation:
#
# 1. There is high positive correlation between SV and the target variable W. Which means teams with more Saves are winning more games.
# 2. There is high negative correlation between RA, ER, ERA and the target W. Which means that teams with less Run Average, Earned runs and Earned Run Average are more likely to win.
# 3. There is also positive correlation between BB, SHO and the target W. Which means that teams with more Base on balls and Shutouts are more likely to win.

# %% [markdown]
# ## Visualizing correlation

# %%
plt.figure(figsize=(25,10))

df_new.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='b')
plt.xlabel('Feature', fontsize=12)
plt.ylabel('Target', fontsize=12)
plt.show()

# %% [markdown]
# From the graph we can see the positive and negative correlation between the features and the target. ER, RA and ERA are negatively correlated to the target variable W. SV is highly positive correlated to W. Possitive correlation between SHO, BB, R, 2B and the target W. The CG and H have very less correlation with the target W.

# %% [markdown]
# ## Checking for skewness

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# There is skewness in H, CG, SHO, SV and E columns.

# %% [markdown]
# ## Removing of skewness

# %%
df_new['H'] = df_new['H'].apply(lambda x: np.cbrt(x))
df_new['CG'] = df_new['CG'].apply(lambda x: np.cbrt(x))
df_new['SHO'] = df_new['SHO'].apply(lambda x: np.cbrt(x))
df_new['E'] = df_new['E'].apply(lambda x: np.cbrt(x))

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO   -0.298136
# SV     0.627480
# E      0.671748
# dtype: float64

# %% [markdown]
# ## Separating features and label

# %%
x=df_new.drop(['W'],axis=1)
y=df_new["W"]

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.728647  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.946162  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.094708  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.351839 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.041742  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.058116 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.555092 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.315000  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.693704  1.202964  0.119526 -0.009484  0.230197
# 16  2.609104  0.511205 -1.122683 -1.297340 -1.327935  0.893823  1.946464
# 17  0.464621  0.028736  0.668344  0.646698  0.702398 -0.555782 -1.066046
# 18  0.033766  2.221778  0.904370  0.903998  0.812742 -0.094672 -0.756001
# 19  0.376492 -1.418671 -1.053264 -1.140102 -1.173453 -0.555782  0.704481
# 20  0.905268 -1.155506 -0.747817 -0.854214 -0.754146  0.486291  0.495072
# 21 -0.994411  1.256840 -0.150808  0.017745  0.128608 -2.329822  0.274630
# 22 -1.415474 -0.629176  0.987674  0.875409  0.989293  0.228786 -0.206072
# 23  0.219817  0.204180  1.667986  1.604423  1.607220 -0.555782 -1.066046
# 24  0.063143 -1.067784 -1.303174 -1.197279 -1.151385  0.893823  1.946464
# 25 -0.906281  0.423484 -0.858889 -0.568326 -0.533457  1.063794  1.454407
# 26  0.591919  2.134056  0.335129  0.317927  0.172746 -0.555782  0.274630
# 27  0.738802 -0.058985  0.585040  0.260750  0.283090 -0.555782 -1.407219
# 28  0.307947  0.598927  2.153924  2.319144  2.379630  0.486291 -2.225231
#
#           SV         E
# 0   1.643157 -0.448230
# 1   0.211006 -0.604643
# 2  -0.700362 -1.171994
# 3  -0.830557  0.514746
# 4  -1.090948 -0.604643
# 5   0.601593 -0.067301
# 6  -0.049384 -1.340220
# 7   2.163939  0.081247
# 8  -0.439971  0.227724
# 9   0.211006  1.720140
# 10 -0.570166 -0.683760
# 11  0.341202 -0.067301
# 12  0.211006  0.007236
# 13 -2.002317  2.155971
# 14  2.424329  0.154740
# 15  1.382766  1.908962
# 16  0.601593  1.200582
# 17 -0.439971  1.528116
# 18 -1.090948 -0.294169
# 19  0.861984 -0.448230
# 20 -0.309775 -0.294169
# 21 -1.090948 -1.340220
# 22  0.080811 -0.294169
# 23 -1.090948  1.592488
# 24  0.471397 -1.511384
# 25 -0.309775 -1.255748
# 26  0.080811 -0.604643
# 27 -0.309775 -0.142374
# 28 -0.960753  0.081247

# %% [markdown]
# ## Checking Variance Inflation Factor VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#      VIF values Features
# 0      7.023599        R
# 1     16.243130       AB
# 2      8.969921        H
# 3      3.848037       2B
# 4      3.104804       3B
# 5      8.352753       HR
# 6      3.424399       BB
# 7      2.751507       SO
# 8      1.920821       SB
# 9    191.905524       RA
# 10  1749.579681       ER
# 11  1372.620432      ERA
# 12     2.753127       CG
# 13     3.158823      SHO
# 14     4.689527       SV
# 15     2.184765        E

# %% [markdown]
# By checking the VIF values we can find the features causing multicollineraty problem.
#
# 1. AB, RA, ER, ERA have VIF greater than 10 which means they have high correlation with other features.
# 2. There is moderate multicollineraty between H, SV with other features.
#
# We will drop one of the columns to see if the same issue still exist.

# %%
# Dropping the ER column

x = x.drop("ER", axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values Features
# 0     6.451920        R
# 1     7.123732       AB
# 2     8.646289        H
# 3     3.556544       2B
# 4     3.098555       3B
# 5     7.493345       HR
# 6     3.424389       BB
# 7     2.751042       SO
# 8     1.780530       SB
# 9   140.954156       RA
# 10  141.902095      ERA
# 11    2.508891       CG
# 12    2.989327      SHO
# 13    2.462612       SV
# 14    2.109598        E

# %% [markdown]
# We still have High VIF in ERA and RA columns. Let's remove RA column.

# %%
# Dropping the RA column

x = x.drop("RA", axis=1)

# %%
# Checking again VIF

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF values Features
# 0     6.446332        R
# 1     4.489579       AB
# 2     7.293600        H
# 3     3.509620       2B
# 4     3.029998       3B
# 5     6.443117       HR
# 6     3.125271       BB
# 7     2.273948       SO
# 8     1.744698       SB
# 9     5.292631      ERA
# 10    2.490060       CG
# 11    2.900416      SHO
# 12    2.372441       SV
# 13    2.056577        E

# %% [markdown]
# We have solved multicolinearity issue.

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## Finding the best random state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.968655318467163 on random state 75

# %% [markdown]
# The best accuracy is 97% on random state 75.

# %% [markdown]
# ## Creating train test split

# %%
x=df_new.drop('W', axis=1)
x
# Out:
#       R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  11.439506  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  11.049365  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  11.173556  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  11.136051  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  11.485173  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  11.178893  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  11.106405  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  11.141425  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  11.434409  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  11.237270  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  11.087457  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  11.000000  243  21  176  435  1150   52  675  630  3.94
# 13  656  5544  11.130673  262  22  198  478  1336   69  726  677  4.16
# 14  694  5600  11.200191  277  46  146  475  1119   78  729  664  4.14
# 15  647  5484  11.149475  288  39  137  506  1267   69  525  478  2.94
# 16  697  5631  11.349650  292  27  140  461  1322   98  596  532  3.21
# 17  689  5491  11.027480  272  30  171  567  1518   95  608  546  3.36
# 18  655  5480  11.127982  274  34  145  412  1299   84  737  682  4.28
# 19  640  5571  11.138739  257  27  167  496  1255  134  754  700  4.33
# 20  683  5527  11.054823  295  17  177  488  1290   51  613  557  3.43
# 21  703  5428  11.087457  265  13  177  539  1344   57  635  577  3.62
# 22  613  5463  11.239909  236  40  120  375  1150  112  678  638  4.02
# 23  573  5420  11.082031  251  18  100  471  1107   69  760  698  4.41
# 24  626  5529  11.117204  272  37  130  387  1274   88  809  749  4.69
# 25  667  5385  11.041168  263  26  187  563  1258   59  595  553  3.44
# 26  696  5565  11.411418  288  39  136  457  1159   93  627  597  3.72
# 27  720  5649  11.431859  289  48  154  490  1312  132  713  659  4.04
# 28  650  5457  10.980682  260  36  148  426  1327   82  731  655  4.09
# 29  737  5572  11.393471  274  49  186  388  1283   97  844  799  5.04
#
#           CG       SHO  SV         E
# 0   1.259921  2.000000  56  4.447960
# 1   1.259921  2.289428  45  4.414005
# 2   2.223980  2.154435  38  4.290840
# 3   1.912931  2.080084  37  4.657010
# 4   1.912931  2.289428  35  4.414005
# 6   1.442250  1.587401  48  4.530655
# 7   0.000000  2.154435  43  4.254321
# 8   1.000000  2.289428  60  4.562903
# 9   1.442250  2.154435  40  4.594701
# 10  1.709976  2.080084  45  4.918685
# 11  1.709976  2.351335  39  4.396830
# 12  1.259921  2.289428  46  4.530655
# 13  1.817121  2.289428  45  4.546836
# 14  1.709976  2.466212  28  5.013298
# 15  1.000000  2.466212  62  4.578857
# 16  0.000000  2.351335  54  4.959676
# 17  1.817121  2.758924  48  4.805896
# 18  1.000000  1.912931  40  4.876999
# 19  1.259921  2.000000  35  4.481405
# 20  1.000000  2.410142  50  4.447960
# 21  1.587401  2.351335  41  4.481405
# 22  0.000000  2.289428  35  4.254321
# 23  1.442250  2.154435  44  4.481405
# 24  1.000000  1.912931  35  4.890973
# 25  1.817121  2.758924  47  4.217163
# 26  1.912931  2.620741  41  4.272659
# 27  1.000000  2.289428  44  4.414005
# 28  1.000000  1.817121  41  4.514357
# 29  1.587401  1.587401  36  4.562903

# %%
y=y=df_new['W']
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=10)

# %%
x_train.shape
# Out:
# (20, 16)

# %%
y_train.shape
# Out:
# (20,)

# %%
x_test.shape
# Out:
# (9, 16)

# %%
y_test.shape
# Out:
# (9,)

# %% [markdown]
# We have regression problem.

# %% [markdown]
# ## Linear Regression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.9954478389656357

# %%
#Predicted Values

lrpred=lr.predict(x_test)
lrpred
# Out:
# array([99.72549936, 98.79964973, 94.49311116, 68.81900144, 95.07362721,
#        77.66486087, 93.70263725, 67.31896335, 83.22487126])

# %%
print('R2_score: ', r2_score(y_test,lrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,lrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,lrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,lrpred)))
# Out:
# R2_score:  -0.7455130797751865
# Mean Absolute Error:  10.862841289017029
# Mean Squared Error:  169.81040825467247
# Root Mean Squared Error:  13.031132270630687

# %% [markdown]
# ## Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtrpred=dtr.predict(x_test)

# %%
dtr.score(x_train, y_train)
# Out:
# 1.0

# %%
print('R2_score: ', r2_score(y_test,dtrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,dtrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,dtrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,dtrpred)))
# Out:
# R2_score:  0.35012690355329945
# Mean Absolute Error:  6.111111111111111
# Mean Squared Error:  63.22222222222222
# Root Mean Squared Error:  7.951240294584375

# %% [markdown]
# ## Support Vector Regressor

# %%
svr=SVR()
svr.fit(x_train,y_train)
svrpred=svr.predict(x_test)

# %%
svr.score(x_train, y_train)
# Out:
# -0.009106577435092023

# %%
print('R2_score: ', r2_score(y_test,svrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,svrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,svrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,svrpred)))
# Out:
# R2_score:  -0.048988444183995616
# Mean Absolute Error:  7.550036211396391
# Mean Squared Error:  102.04974000209735
# Root Mean Squared Error:  10.101967135271098

# %% [markdown]
# ## Random Forest Regressor

# %%
rfr=RandomForestRegressor(n_estimators=200, random_state=42)
rfr.fit(x_train, y_train)
rfrpred= rfr.predict(x_test)

# %%
rfr.score(x_train, y_train)
# Out:
# 0.9493497635546398

# %%
print('R2_score: ', r2_score(y_test,rfrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,rfrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,rfrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,rfrpred)))
# Out:
# R2_score:  0.6221079600253809
# Mean Absolute Error:  4.862777777777778
# Mean Squared Error:  36.76283055555553
# Root Mean Squared Error:  6.063235980526861

# %% [markdown]
# ## AdaBoost Regressor

# %%
abr=AdaBoostRegressor()
abr.fit(x_train,y_train)
abrpred=abr.predict(x_test)

# %%
abr.score(x_train, y_train)
# Out:
# 0.987820332740269

# %%
print('R2_score: ', r2_score(y_test,abrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,abrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,abrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,abrpred)))
# Out:
# R2_score:  0.6416445081839841
# Mean Absolute Error:  4.787566137566137
# Mean Squared Error:  34.862237969261784
# Root Mean Squared Error:  5.904425286957384

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge

rr=Ridge()
rr.fit(x_train,y_train)
rrpred=rr.predict(x_test)

# %%
rr.score(x_train, y_train)
# Out:
# 0.9784387847132944

# %%
print('R2_score: ', r2_score(y_test,rrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test,rrpred))
print('Mean Squared Error: ', mean_squared_error(y_test,rrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test,rrpred)))
# Out:
# R2_score:  0.1324795840905294
# Mean Absolute Error:  8.354874985183194
# Mean Squared Error:  84.39581330082257
# Root Mean Squared Error:  9.186719398175965

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso

lasso=Lasso()
lasso.fit(x_train,y_train)
lassopred=lasso.predict(x_test)

# %%
lasso.score(x_train, y_train)
# Out:
# 0.9629507543126857

# %%
print('R2_score: ', r2_score(y_test, lassopred))
print('Mean Absolute Error: ', mean_absolute_error(y_test, lassopred))
print('Mean Squared Error: ', mean_squared_error(y_test, lassopred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, lassopred)))
# Out:
# R2_score:  0.4027052395578302
# Mean Absolute Error:  6.794520938127641
# Mean Squared Error:  58.107193978818486
# Root Mean Squared Error:  7.6228074866691005

# %% [markdown]
# ## KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
knrpred=knr.predict(x_test)

# %%
knr.score(x_train, y_train)
# Out:
# 0.6369322970315572

# %%
print('R2_score: ', r2_score(y_test, knrpred))
print('Mean Absolute Error: ', mean_absolute_error(y_test, knrpred))
print('Mean Squared Error: ', mean_squared_error(y_test, knrpred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, knrpred)))
# Out:
# R2_score:  0.5128578680203046
# Mean Absolute Error:  5.800000000000001
# Mean Squared Error:  47.39111111111111
# Root Mean Squared Error:  6.88412021329604

# %% [markdown]
# ### Best accuracy we get with Decision Tree Regressor. Maximum r2_score we get with AdaBoost Regressor - 0.64.

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#CV score for Linear Regression

score=cross_val_score(lr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,lrpred)-score.mean())*100)
# Out:
# Score:  [ 0.63256022 -0.63224596  0.59848972 -0.43616736 -0.9831155 ]
# Mean Score:  -0.16409577882339849
# Std deviation:  0.6603299565973945
# Difference between R2 score and CVS is:  -58.1417300951788

# %%
#CV score for DTR

score=cross_val_score(dtr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,dtrpred)-score.mean())*100)
# Out:
# Score:  [ -1.67272727 -11.56578947   0.34588038   0.3852459    0.52830189]
# Mean Score:  -2.395817714640688
# Std deviation:  4.656456605584784
# Difference between R2 score and CVS is:  274.5944618193987

# %%
#CV score for SVR

score=cross_val_score(svr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,svrpred)-score.mean())*100)
# Out:
# Score:  [-0.14625031 -1.25789583 -0.06354594 -0.64187589 -0.03412775]
# Mean Score:  -0.4287391438238234
# Std deviation:  0.4694277911961613
# Difference between R2 score and CVS is:  37.975069963982776

# %%
#CV score for RFR

score=cross_val_score(rfr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,rfrpred)-score.mean())*100)
# Out:
# Score:  [ 0.18115665 -5.99741414  0.47056909  0.41523529  0.90211483]
# Mean Score:  -0.8056676577369892
# Std deviation:  2.6062984886552067
# Difference between R2 score and CVS is:  142.777561776237

# %%
#CV score for ABR

score=cross_val_score(abr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,abrpred)-score.mean())*100)
# Out:
# Score:  [ 0.27428736 -8.18773392  0.61680881  0.43567154  0.86366073]
# Mean Score:  -1.1994610962537178
# Std deviation:  3.4996245030436026
# Difference between R2 score and CVS is:  184.1105604437702

# %%
#CV score for Ridge Regressor

score=cross_val_score(rr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,rrpred)-score.mean())*100)
# Out:
# Score:  [ 0.53357816 -1.16464894  0.65463627  0.77822498  0.63231291]
# Mean Score:  0.28682067508434156
# Std deviation:  0.729902004506366
# Difference between R2 score and CVS is:  -15.434109099381216

# %%
#CV score for Lasso Regressor

score=cross_val_score(lasso,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,lassopred)-score.mean())*100)
# Out:
# Score:  [ 0.51382076 -1.32045094  0.66257312  0.87903346  0.8328386 ]
# Mean Score:  0.3135629997231159
# Std deviation:  0.8272021265084899
# Difference between R2 score and CVS is:  8.91422398347143

# %%
#CV score for KNeighbors Regressor

score=cross_val_score(knr,x,y, cv=5)
print("Score: " ,score)
print("Mean Score: ",score.mean())
print("Std deviation: ",score.std())
print("Difference between R2 score and CVS is: ",(r2_score(y_test,knrpred)-score.mean())*100)
# Out:
# Score:  [-0.65572727 -2.62052632  0.37716437  0.2544918   0.78667453]
# Mean Score:  -0.3715845781124542
# Std deviation:  1.2192322818204677
# Difference between R2 score and CVS is:  88.44424461327588

# %% [markdown]
# Best accuracy: Decosion Tree Regressor, Linear Regression and AdaBoost Regressor.

# %% [markdown]
# ### Lasso model has high R2 score and least difference between Cross Validation Score and R2 score.

# %% [markdown]
# ## Hyper Rarameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[0.01, 0.1, 1.0, 10.0],
             'fit_intercept':[True,False],
             'max_iter':[0,1000],
             'precompute':[True,False],
             'selection':['cyclic', 'random']}

# %%
GSCV=GridSearchCV(Lasso(),param,cv=5)

# %%
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.0],
#                          'fit_intercept': [True, False], 'max_iter': [0, 1000],
#                          'precompute': [True, False],
#                          'selection': ['cyclic', 'random']})

# %%
GSCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': False,
#  'max_iter': 1000,
#  'precompute': True,
#  'selection': 'cyclic'}

# %%
Final_model=Lasso(alpha=1.0, fit_intercept=False, max_iter=1000, precompute=True, selection= 'cyclic')
Final_model.fit(x_train, y_train)
prediction=Final_model.predict(x_test)

print("R2 score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# R2 score: 0.6226686004922705
# Mean Absolute Error: 5.234909839053507
# Mean Squared Error: 36.7082892360606
# Root Mean Squared Error: 6.058736603951405

# %% [markdown]
# # Saving the model

# %%
import joblib

import joblib

joblib.dump(lasso, 'Baseball Case Study.pkl.obj')
# Out:
# ['Baseball Case Study.pkl.obj']
